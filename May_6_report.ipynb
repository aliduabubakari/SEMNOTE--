# %%
#----------------------START-------------------------------
import requests
from time import time, sleep

API_URL = "http://localhost:3003/api/"
SIGNIN_ENDPOINT = "auth/signin"
DATASETS_ENDPOINT = "dataset/"

class TokenManager:
    def __init__(self, signin_data, signin_headers):
        self.signin_url = f"{API_URL}{SIGNIN_ENDPOINT}"
        self.signin_data = signin_data
        self.signin_headers = signin_headers
        self.token = None
        self.token_expiry = 0

    def get_token(self):
        """
        Obtains the authentication token. If the token is expired, it will refresh it.
        """
        if self.token is None or time() >= self.token_expiry:
            self.refresh_token()
        return self.token

    def refresh_token(self):
        """
        Performs a sign-in request and updates the token and its expiration time.
        """
        try:
            response = requests.post(self.signin_url, headers=self.signin_headers, json=self.signin_data)
            response.raise_for_status()  # Raise an exception if the request was not successful
            user_info = response.json()
            self.token = user_info.get("token")
            self.token_expiry = time() + 3600  # Assuming the token expires in 1 hour
        except requests.RequestException as e:
            print(f"Sign-in request failed: {e}")
            self.token = None
            self.token_expiry = 0

# Example usage
signin_data = {"username": "test", "password": "test"}
signin_headers = {
    "accept": "application/json",
    "content-type": "application/json"
}

token_manager = TokenManager(signin_data, signin_headers)

# Obtain the token
token = token_manager.get_token()
#print("Authentication token:", token)

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# Now, use the detected encoding to read the file with pandas
# Replace 'detected_encoding' with the actual encoding detected by chardet
df = pd.read_csv("JOT sample original.csv", sep='\t', encoding='ISO-8859-1')

# %%
# Assuming df is your DataFrame
df['Fecha_id'] = pd.to_datetime(df['Fecha_id'], format='%Y%m%d')
df['Fecha_id'] = df['Fecha_id'].dt.strftime('%Y-%m-%d')

# %%
import zipfile
import os

# Define the path for the CSV and zip files
csv_file = 'JOT_Date_Transformed2.csv'  # Relative path
zip_file = 'JOT_Date_Transformed2.zip'  # Relative path

# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False)

# Create a zip file containing the CSV
with zipfile.ZipFile(zip_file, 'w', zipfile.ZIP_DEFLATED) as z:
    z.write(csv_file, os.path.basename(csv_file))

# Clean up: remove the CSV file if you don't need it anymore
#os.remove(csv_file)

print("Zip file created successfully.")
# Out:
# Zip file created successfully.

# %%
def get_database_list(api_url, datasets_endpoint, token_manager):
    """
    Retrieves the list of datasets from the API.

    Args:
        api_url (str): The base URL of the API.
        datasets_endpoint (str): The endpoint for retrieving the dataset list.
        token_manager (object): An object that manages the authentication token.

    Returns:
        dict: The JSON response containing the dataset information.
    """
    try:
        url = f"{api_url}{datasets_endpoint}"
        headers = {
            "accept": "application/json",
            "authorization": f"Bearer {token_manager.get_token()}"
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Request failed: {e}")
        return {}
database_list = get_database_list(API_URL, DATASETS_ENDPOINT, token_manager)
database_list
# Out:
# {'meta': {'name': {'label': 'Name',
#    'type': 'link',
#    'props': {'url': '/datasets/:id/tables'}},
#   'description': {'label': 'Description'},
#   'nTables': {'label': 'N. Tables'},
#   'mentions': {'label': 'N. Mentions'},
#   'lastModifiedDate': {'label': 'Last Modified', 'type': 'date'}},
#  'collection': [{'id': '0',
#    'userId': 0,
#    'name': 'Museums',
#    'nTables': 6,
#    'lastModifiedDate': '2023-11-06T10:34:36.196Z'},
#   {'id': '1',
#    'userId': 0,
#    'name': 'JOT BC',
#    'nTables': 7,
#    'lastModifiedDate': '2023-11-06T13:11:29.481Z'},
#   {'id': '2',
#    'userId': 0,
#    'name': 'SN BC',
#    'nTables': 8,
#    'lastModifiedDate': '2023-11-15T09:51:35.102Z'},
#   {'id': '3',
#    'userId': 0,
#    'name': 'InterTwino',
#    'nTables': 7,
#    'lastModifiedDate': '2023-12-15T13:31:24.769Z'},
#   {'id': '4',
#    'userId': 0,
#    'name': 'New Dataset',
#    'nTables': 1,
#    'lastModifiedDate': '2024-04-26T09:04:24.453Z'},
#   {'id': '5',
#    'userId': 0,
#    'name': 'JOT Dataset',
#    'nTables': 1,
#    'lastModifiedDate': '2024-04-27T07:38:21.884Z'},
#   {'id': '9',
#    'userId': 0,
#    'name': 'JOT_PUT_Dataset',
#    'nTables': 1,
#    'lastModifiedDate': '2024-04-29T11:14:41.183Z'},
#   {'id': '10',
#    'userId': 0,
#    'name': 'JOT_PUT_Dataset',
#    'nTables': 1,
#    'lastModifiedDate': '2024-04-30T09:59:33.664Z'},
#   {'id': '11',
#    'userId': 0,
#    'name': 'JOT_test_Dataset',
#    'nTables': 1,
#    'lastModifiedDate': '2024-04-30T14:00:01.361Z'},
#   {'id': '12',
#    'userId': 0,
#    'name': 'JOT_Date_Transformed',
#    'nTables': 1,
#    'lastModifiedDate': '2024-05-02T09:38:10.490Z'},
#   {'id': '13',
#    'userId': 0,
#    'name': 'JOT_May2',
#    'nTables': 1,
#    'lastModifiedDate': '2024-05-06T09:34:53.132Z'}]}

# %%
import requests
import json
import io

# The endpoint URL for adding a dataset
API_URL = "http://localhost:3003/api/"
DATASETS_ENDPOINT = "dataset"
url = f"{API_URL}{DATASETS_ENDPOINT}"

token = token_manager.get_token()

# Set the headers with the token
headers = {
    'Authorization': f'Bearer {token}'
}

# Path to the zip file you want to upload
zip_file_path = 'JOT_Date_Transformed2.zip'

# Open the zip file in binary mode
with open(zip_file_path, 'rb') as file:
    files = {
        'file': (file.name, file, 'application/zip')
    }

    data = {
        'name': 'JOT_May2'
    }

    # Send the POST request to add the dataset
    response = requests.post(url, headers=headers, data=data, files=files, timeout=30)

# Check the response
if response.status_code == 200:
    print("Dataset added successfully!")
    # Extract the dataset ID from the response
    response_data = response.json()
    dataset_id = response_data['datasets'][0]['id']
    print(f"New dataset ID: {dataset_id}")
elif response.status_code == 400:
    # Extract the error message and dataset ID from the response
    response_data = response.json()
    error_message = response_data.get('error', 'Unknown error')
    dataset_id = response_data.get('datasetId')
    print(f"Error: {error_message}")
    print(f"Dataset ID: {dataset_id}")
else:
    print(f"Failed to add dataset: {response.status_code}, {response.text}")
# Out:
# Dataset added successfully!
# New dataset ID: 13

# %%
import requests
import pandas as pd
import json

API_URL = "http://localhost:3003/api/"
DATASETS_ENDPOINT = "dataset/"

def get_dataset_tables(dataset_id, token_manager):
    """
    Retrieves the list of tables for a given dataset.
    
    Args:
        dataset_id (str): The ID of the dataset.
        token_manager (TokenManager): An instance of the TokenManager class.
    
    Returns:
        list: A list of tables in the dataset.
    """
    try:
        url = f"{API_URL}{DATASETS_ENDPOINT}{dataset_id}/table"
        headers = {
            "accept": "application/json",
            "authorization": f"Bearer {token_manager.get_token()}"
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception if the request was not successful
        return response.json()["collection"]
    except (requests.RequestException, json.JSONDecodeError, KeyError) as e:
        print(f"Error getting dataset tables: {e}")
        return []


def get_table(dataset_id, table_id, token_manager):
    """
    Retrieves a table by its ID from a specific dataset.
    
    Args:
        dataset_id (str): The ID of the dataset.
        table_id (str): The ID of the table to retrieve.
        token_manager (TokenManager): An instance of the TokenManager class.
    
    Returns:
        dict: The table data in JSON format.
    """
    url = f"{API_URL}{DATASETS_ENDPOINT}{dataset_id}/table/{table_id}"
    headers = {
        "Authorization": f"Bearer {token_manager.get_token()}",
        "Accept": "application/json"
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception if the request was not successful
        table_data = response.json()
        
        return table_data
    
    except requests.RequestException as e:
        print(f"Error occurred while retrieving the table data: {e}")
        return None

def get_table_by_name(dataset_id, table_name, token_manager):
    """
    Retrieves a table by its name from a specific dataset.
    
    Args:
        dataset_id (str): The ID of the dataset.
        table_name (str): The name of the table to retrieve.
        token_manager (TokenManager): An instance of the TokenManager class.
    
    Returns:
        dict: The table data in JSON format.
    """
    tables = get_dataset_tables(dataset_id, token_manager)
    
    for table in tables:
        if table["name"] == table_name:
            table_id = table["id"]
            return get_table(dataset_id, table_id, token_manager)
    
    print(f"Table '{table_name}' not found in the dataset.")
    return None

# Example usage
dataset_id = "13"
table_name = "JOT_Date_Transformed2"  # Replace with the desired table name

table_json = get_table_by_name(dataset_id, table_name, token_manager)

if table_json is not None:
    # Process the table data as needed
    print("Table JSON:")
    print(json.dumps(table_json, indent=2))
# Out:
# Table JSON:
# {
#   "table": {
#     "id": "44",
#     "idDataset": "13",
#     "name": "JOT_Date_Transformed2",
#     "nCols": 40,
#     "nRows": 18,
#     "nCells": 720,
#     "nCellsReconciliated": 0,
#     "lastModifiedDate": "2024-05-06T09:34:53.131Z"
#   },
#   "columns": {
#     "Fecha_id": {
#       "id": "Fecha_id",
#       "label": "Fecha_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cuenta_id": {
#       "id": "Cuenta_id",
#       "label": "Cuenta_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Campa\u00f1a_id": {
#       "id": "Campa\u00f1a_id",
#       "label": "Campa\u00f1a_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Grupo_id": {
#       "id": "Grupo_id",
#       "label": "Grupo_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Keyword_id": {
#       "id": "Keyword_id",
#       "label": "Keyword_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "City_id": {
#       "id": "City_id",
#       "label": "City_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "State_id": {
#       "id": "State_id",
#       "label": "State_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Country_id": {
#       "id": "Country_id",
#       "label": "Country_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Keyword": {
#       "id": "Keyword",
#       "label": "Keyword",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones": {
#       "id": "Impresiones",
#       "label": "Impresiones",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks": {
#       "id": "Clicks",
#       "label": "Clicks",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc": {
#       "id": "Cpc",
#       "label": "Cpc",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "QualityScore": {
#       "id": "QualityScore",
#       "label": "QualityScore",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "City": {
#       "id": "City",
#       "label": "City",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "County": {
#       "id": "County",
#       "label": "County",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Country": {
#       "id": "Country",
#       "label": "Country",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_q1": {
#       "id": "Impresiones_q1",
#       "label": "Impresiones_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_q3": {
#       "id": "Impresiones_q3",
#       "label": "Impresiones_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_med": {
#       "id": "Impresiones_med",
#       "label": "Impresiones_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_iqr": {
#       "id": "Impresiones_iqr",
#       "label": "Impresiones_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_max": {
#       "id": "Impresiones_max",
#       "label": "Impresiones_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_min": {
#       "id": "Impresiones_min",
#       "label": "Impresiones_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_q1": {
#       "id": "Clicks_q1",
#       "label": "Clicks_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_q3": {
#       "id": "Clicks_q3",
#       "label": "Clicks_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_med": {
#       "id": "Clicks_med",
#       "label": "Clicks_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_iqr": {
#       "id": "Clicks_iqr",
#       "label": "Clicks_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_max": {
#       "id": "Clicks_max",
#       "label": "Clicks_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_min": {
#       "id": "Clicks_min",
#       "label": "Clicks_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_q1": {
#       "id": "Cpc_q1",
#       "label": "Cpc_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_q3": {
#       "id": "Cpc_q3",
#       "label": "Cpc_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_med": {
#       "id": "Cpc_med",
#       "label": "Cpc_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_iqr": {
#       "id": "Cpc_iqr",
#       "label": "Cpc_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_max": {
#       "id": "Cpc_max",
#       "label": "Cpc_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_min": {
#       "id": "Cpc_min",
#       "label": "Cpc_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_q1": {
#       "id": "Qs_q1",
#       "label": "Qs_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_q3": {
#       "id": "Qs_q3",
#       "label": "Qs_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_med": {
#       "id": "Qs_med",
#       "label": "Qs_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_iqr": {
#       "id": "Qs_iqr",
#       "label": "Qs_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_max": {
#       "id": "Qs_max",
#       "label": "Qs_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_min": {
#       "id": "Qs_min",
#       "label": "Qs_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     }
#   },
#   "rows": {
#     "r0": {
#       "id": "r0",
#       "cells": {
#         "Fecha_id": {
#           "id": "r0$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r0$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r0$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r0$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r0$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r0$City_id",
#           "label": "1023619",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r0$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r0$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r0$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r0$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r0$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r0$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r0$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r0$City",
#           "label": "Chardon",
#           "metadata": []
#         },
#         "County": {
#           "id": "r0$County",
#           "label": "Ohio",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r0$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r0$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r0$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r0$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r0$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r0$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r0$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r0$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r0$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r0$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r0$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r0$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r0$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r0$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r0$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r0$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r0$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r0$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r0$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r0$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r0$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r0$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r0$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r0$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r0$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r1": {
#       "id": "r1",
#       "cells": {
#         "Fecha_id": {
#           "id": "r1$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r1$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r1$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r1$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r1$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r1$City_id",
#           "label": "1023631",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r1$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r1$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r1$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r1$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r1$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r1$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r1$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r1$City",
#           "label": "Cleveland",
#           "metadata": []
#         },
#         "County": {
#           "id": "r1$County",
#           "label": "Ohio",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r1$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r1$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r1$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r1$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r1$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r1$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r1$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r1$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r1$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r1$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r1$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r1$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r1$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r1$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r1$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r1$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r1$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r1$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r1$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r1$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r1$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r1$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r1$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r1$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r1$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r2": {
#       "id": "r2",
#       "cells": {
#         "Fecha_id": {
#           "id": "r2$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r2$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r2$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r2$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r2$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r2$City_id",
#           "label": "1016367",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r2$State_id",
#           "label": "21147",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r2$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r2$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r2$Impresiones",
#           "label": "5",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r2$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r2$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r2$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r2$City",
#           "label": "Chicago",
#           "metadata": []
#         },
#         "County": {
#           "id": "r2$County",
#           "label": "Illinois",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r2$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r2$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r2$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r2$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r2$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r2$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r2$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r2$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r2$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r2$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r2$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r2$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r2$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r2$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r2$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r2$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r2$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r2$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r2$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r2$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r2$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r2$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r2$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r2$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r2$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r3": {
#       "id": "r3",
#       "cells": {
#         "Fecha_id": {
#           "id": "r3$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r3$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r3$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r3$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r3$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r3$City_id",
#           "label": "1027744",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r3$State_id",
#           "label": "21180",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r3$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r3$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r3$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r3$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r3$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r3$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r3$City",
#           "label": "Seattle",
#           "metadata": []
#         },
#         "County": {
#           "id": "r3$County",
#           "label": "Washington",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r3$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r3$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r3$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r3$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r3$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r3$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r3$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r3$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r3$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r3$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r3$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r3$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r3$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r3$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r3$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r3$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r3$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r3$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r3$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r3$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r3$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r3$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r3$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r3$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r3$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r4": {
#       "id": "r4",
#       "cells": {
#         "Fecha_id": {
#           "id": "r4$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r4$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r4$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r4$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r4$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r4$City_id",
#           "label": "1016359",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r4$State_id",
#           "label": "21147",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r4$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r4$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r4$Impresiones",
#           "label": "3",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r4$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r4$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r4$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r4$City",
#           "label": "Champaign",
#           "metadata": []
#         },
#         "County": {
#           "id": "r4$County",
#           "label": "Illinois",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r4$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r4$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r4$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r4$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r4$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r4$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r4$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r4$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r4$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r4$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r4$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r4$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r4$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r4$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r4$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r4$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r4$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r4$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r4$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r4$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r4$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r4$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r4$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r4$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r4$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r5": {
#       "id": "r5",
#       "cells": {
#         "Fecha_id": {
#           "id": "r5$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r5$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r5$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r5$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r5$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r5$City_id",
#           "label": "1023815",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r5$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r5$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r5$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r5$Impresiones",
#           "label": "3",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r5$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r5$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r5$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r5$City",
#           "label": "Marion",
#           "metadata": []
#         },
#         "County": {
#           "id": "r5$County",
#           "label": "Ohio",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r5$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r5$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r5$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r5$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r5$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r5$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r5$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r5$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r5$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r5$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r5$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r5$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r5$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r5$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r5$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r5$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r5$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r5$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r5$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r5$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r5$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r5$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r5$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r5$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r5$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r6": {
#       "id": "r6",
#       "cells": {
#         "Fecha_id": {
#           "id": "r6$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r6$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r6$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r6$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r6$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r6$City_id",
#           "label": "1025531",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r6$State_id",
#           "label": "21173",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r6$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r6$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r6$Impresiones",
#           "label": "3",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r6$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r6$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r6$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r6$City",
#           "label": "Conway",
#           "metadata": []
#         },
#         "County": {
#           "id": "r6$County",
#           "label": "South Carolina",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r6$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r6$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r6$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r6$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r6$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r6$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r6$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r6$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r6$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r6$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r6$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r6$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r6$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r6$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r6$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r6$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r6$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r6$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r6$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r6$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r6$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r6$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r6$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r6$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r6$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r7": {
#       "id": "r7",
#       "cells": {
#         "Fecha_id": {
#           "id": "r7$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r7$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r7$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r7$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r7$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r7$City_id",
#           "label": "1026730",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r7$State_id",
#           "label": "21176",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r7$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r7$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r7$Impresiones",
#           "label": "2",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r7$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r7$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r7$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r7$City",
#           "label": "Richmond",
#           "metadata": []
#         },
#         "County": {
#           "id": "r7$County",
#           "label": "Texas",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r7$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r7$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r7$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r7$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r7$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r7$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r7$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r7$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r7$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r7$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r7$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r7$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r7$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r7$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r7$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r7$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r7$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r7$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r7$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r7$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r7$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r7$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r7$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r7$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r7$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r8": {
#       "id": "r8",
#       "cells": {
#         "Fecha_id": {
#           "id": "r8$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r8$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r8$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r8$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r8$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r8$City_id",
#           "label": "9052594",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r8$State_id",
#           "label": "21164",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r8$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r8$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r8$Impresiones",
#           "label": "2",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r8$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r8$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r8$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r8$City",
#           "label": "Old Bridge Township",
#           "metadata": []
#         },
#         "County": {
#           "id": "r8$County",
#           "label": "New Jersey",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r8$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r8$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r8$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r8$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r8$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r8$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r8$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r8$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r8$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r8$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r8$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r8$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r8$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r8$Cpc_q1",
# ...
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r14$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r14$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r14$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r14$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r14$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r14$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r14$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r14$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r14$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r14$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r14$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r14$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r15": {
#       "id": "r15",
#       "cells": {
#         "Fecha_id": {
#           "id": "r15$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r15$Cuenta_id",
#           "label": "1150766542",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r15$Campa\u00f1a_id",
#           "label": "18850329589",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r15$Grupo_id",
#           "label": "148000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r15$Keyword_id",
#           "label": "352000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r15$City_id",
#           "label": "1021141",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r15$State_id",
#           "label": "21160",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r15$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r15$Keyword",
#           "label": "armed forces recruiting",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r15$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r15$Clicks",
#           "label": "4",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r15$Cpc",
#           "label": "6900000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r15$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r15$City",
#           "label": "Havelock",
#           "metadata": []
#         },
#         "County": {
#           "id": "r15$County",
#           "label": "North Carolina",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r15$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r15$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r15$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r15$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r15$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r15$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r15$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r15$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r15$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r15$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r15$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r15$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r15$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r15$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r15$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r15$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r15$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r15$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r15$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r15$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r15$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r15$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r15$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r15$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r15$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r16": {
#       "id": "r16",
#       "cells": {
#         "Fecha_id": {
#           "id": "r16$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r16$Cuenta_id",
#           "label": "1150766542",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r16$Campa\u00f1a_id",
#           "label": "18850329589",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r16$Grupo_id",
#           "label": "148000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r16$Keyword_id",
#           "label": "352000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r16$City_id",
#           "label": "9052608",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r16$State_id",
#           "label": "21136",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r16$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r16$Keyword",
#           "label": "armed forces recruiting",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r16$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r16$Clicks",
#           "label": "4",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r16$Cpc",
#           "label": "6900000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r16$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r16$City",
#           "label": "Oro Valley",
#           "metadata": []
#         },
#         "County": {
#           "id": "r16$County",
#           "label": "Arizona",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r16$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r16$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r16$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r16$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r16$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r16$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r16$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r16$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r16$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r16$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r16$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r16$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r16$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r16$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r16$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r16$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r16$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r16$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r16$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r16$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r16$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r16$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r16$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r16$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r16$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r17": {
#       "id": "r17",
#       "cells": {
#         "Fecha_id": {
#           "id": "r17$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r17$Cuenta_id",
#           "label": "1333143884",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r17$Campa\u00f1a_id",
#           "label": "20071681157",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r17$Grupo_id",
#           "label": "148000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r17$Keyword_id",
#           "label": "352000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r17$City_id",
#           "label": "1014964",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r17$State_id",
#           "label": "21142",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r17$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r17$Keyword",
#           "label": "armed forces recruiting",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r17$Impresiones",
#           "label": "39",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r17$Clicks",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r17$Cpc",
#           "label": "20000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r17$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r17$City",
#           "label": "Brandon",
#           "metadata": []
#         },
#         "County": {
#           "id": "r17$County",
#           "label": "Florida",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r17$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r17$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r17$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r17$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r17$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r17$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r17$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r17$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r17$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r17$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r17$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r17$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r17$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r17$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r17$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r17$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r17$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r17$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r17$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r17$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r17$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r17$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r17$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r17$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r17$Qs_min",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     }
#   }
# }

# %%
import requests
import pandas as pd
import json

SEMTUI_URI = "http://localhost:3003/api"  # Make sure this points to your actual API

def getReconciliatorData():
    """
    Retrieves reconciliator data from the backend

    :return: data of reconciliator services in JSON format
    """
    response = requests.get(SEMTUI_URI + '/reconciliators/list')
    return json.loads(response.text)

def cleanServiceList(serviceList):
    """
    Cleans and formats the service list

    :serviceList: data regarding available services
    :return: dataframe containing reconciliators information
    """
    serviceList = serviceList
    reconciliators = pd.DataFrame(columns=["id", "relativeUrl", "name"])
    for reconciliator in serviceList:
        reconciliators.loc[len(reconciliators)] = [
            reconciliator["id"], reconciliator["relativeUrl"], reconciliator["name"]]
    return reconciliators

def getReconciliatorsList():
    """
    Provides a list of available reconciliators with their main information

    :return: a dataframe containing reconciliators and their information
    """
    response = getReconciliatorData()
    return cleanServiceList(response)



def getExtenderData():
    """
    Retrieves extender data from the backend

    :return: data of extension services in JSON format
    """
    response = requests.get(SEMTUI_URI + '/extenders/list')
    return json.loads(response.text)

def getExtendersList():
    """
    Provides a list of available extenders with their main information

    :return: a dataframe containing extenders and their information
    """
    response = getExtenderData()
    return cleanServiceList(response)

# %%
getReconciliatorsList()
# Out:
#               id relativeUrl               name
# 0  hereGeoCoords       /here  Here Geo Location
# 1       wikidata   /wikidata           Wikidata

# %%
getExtendersList()
# Out:
#                                id         relativeUrl                            name
# 0                       columnExt                                     Column Extender
# 1                       hereRoute                                          HERE Route
# 2               openMeteoExtender                               Open Meteo Properties
# 3        parametricWikiDataSPARQL  /wikidata/entities      Parametric Wikidata SPARQL
# 4  parametricWikiDataSelectSPARQL  /wikidata/entities          Wikidata Select SPARQL
# 5           wikidataGeoProperties  /wikidata/entities         Wikidata Geo Properties
# 6     wikidataGeoPropertiesSPARQL  /wikidata/entities  Wikidata Geo Properties SPARQL

# %%
SEMTUI_URI = "http://localhost:3003/api/"  # Ensure this points to your actual API endpoint

def getReconciliatorData():
    """
    Retrieves reconciliator data from the backend
    :return: data of reconciliator services in JSON format
    """
    try:
        response = requests.get(SEMTUI_URI + '/reconciliators/list')
        response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error occurred while retrieving reconciliator data: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error occurred while parsing reconciliator data: {e}")
        print(f"Response content: {response.text}")
        return None

def getReconciliator(idReconciliator, response):
    """
    Function that, given the reconciliator's ID, returns a dictionary 
    with all the service information

    :idReconciliator: the ID of the reconciliator in question
    :return: a dictionary with the reconciliator's information
    """
    for reconciliator in response:
        if reconciliator['id'] == idReconciliator:
            return {
                'uri': reconciliator['uri'],
                'prefix': reconciliator['prefix'],
                'name': reconciliator['name'],
                'relativeUrl': reconciliator['relativeUrl']
            }
    return None

def createReconciliationPayload(table, columnName, idReconciliator):
    """
    Creates the payload for the reconciliation request

    :table: table in raw format
    :columnName: the name of the column to reconcile
    :idReconciliator: the id of the reconciliation service to use
    :return: the request payload
    """
    rows = []
    rows.append({"id": 'column$index', "label": columnName})
    for row in table['rows'].keys():
        rows.append({"id": row+"$"+columnName,
                    "label": table['rows'][row]['cells'][columnName]['label']})
    return {"serviceId": idReconciliator, "items": rows}

def parseNameField(name, uriReconciliator, idEntity):
    """
    The actual function that changes the name format to the one required for visualization

    :name: entity name
    :uriReconciliator: the URI of the affiliated knowledge graph
    :idEntity: entity ID
    :return: the name in the correct format
    """
    return {
        'value': name,
        'uri': uriReconciliator + idEntity
    }

def createCellMetadataNameField(metadata, idReconciliator, reconciliatorResponse):
    """
    Refactor of the name field within cell-level metadata
    necessary for visualization within SEMTUI

    :metadata: column-level metadata
    :idReconciliator: ID of the reconciliator performed in the operation
    :reconciliatorResponse: response containing reconciliator information
    :return: metadata containing the name field in the new format
    """
    for row in range(len(metadata)):
        try:
            for item in range(len(metadata[row]["metadata"])):
                value = metadata[row]["metadata"][item]['name']
                uri = metadata[row]["metadata"][item]['id']
                metadata[row]["metadata"][item]['name'] = parseNameField(value, getReconciliator(
                    idReconciliator, reconciliatorResponse)['uri'], uri.split(':')[1])
        except:
            return []
    return metadata

def calculateScoreBoundCell(metadata):
    """
    Calculates the min and max value of the score of the results obtained for
    a single cell

    :metadata: metadata of a single cell
    :return: a dictionary containing the two values
    """
    try:
        scoreList = [item['score'] for item in metadata]
        return {'lowestScore': min(scoreList), 'highestScore': max(scoreList)}
    except:
        return {'lowestScore': 0, 'highestScore': 0}

def valueMatchCell(metadata):
    """
    Returns whether a cell has obtained a match or not

    :metadata: cell-level metadata
    :return: True or False based on the match occurrence
    """
    for item in metadata:
        if item['match'] == True:
            return True
    return False

def createAnnotationMetaCell(metadata):
    """
    Creates the annotationMeta field at the cell level, 
    which will then be inserted into the table

    :metadata: cell-level metadata
    :return: the dictionary with data regarding annotationMeta
    """
    scoreBound = calculateScoreBoundCell(metadata)
    return {'annotated': True,
            'match': {'value': valueMatchCell(metadata)},
            'lowestScore': scoreBound['lowestScore'],
            'highestScore': scoreBound['highestScore']}


def updateMetadataCells(table, metadata):
    """
    Allows inserting new cell-level metadata

    :table: table in raw format
    :metadata: cell-level metadata
    :return: the table in raw format with metadata
    """
    for item in metadata:
        item["id"] = item["id"].split("$")
        try:
            table["rows"][item["id"][0]]["cells"][item["id"]
                                                  [1]]["metadata"] = item["metadata"]
            table["rows"][item["id"][0]]["cells"][item["id"][1]
                                                  ]["annotationMeta"] = createAnnotationMetaCell(item["metadata"])
        except:
            print("")
    return table

def calculateNCellsReconciliatedColumn(table, columnName):
    """
    Calculates the number of reconciled cells within 
    a column

    :table: table in raw format
    :columnName: name of the column in question
    :return: the number of reconciled cells
    """
    cellsReconciliated = 0
    rowsIndex = table["rows"].keys()
    for row in rowsIndex:
        try:
            if table['rows'][row]['cells'][columnName]['annotationMeta']["annotated"] == True:
                cellsReconciliated += 1
        except:
            cellsReconciliated = cellsReconciliated
    return cellsReconciliated


def createContextColumn(table, columnName, idReconciliator, reconciliatorResponse):
    """
    Creates the context field at the column level by retrieving the necessary data

    :table: table in raw format
    :columnName: the name of the column for which the context is being created
    :idReconciliator: the ID of the reconciliator used for the column
    :reconciliatorResponse: response containing reconciliator information
    :return: the context field of the column
    """
    nCells = len(table["rows"].keys())
    reconciliator = getReconciliator(idReconciliator, reconciliatorResponse)
    return {reconciliator['prefix']: {
            'uri': reconciliator['uri'],
            'total': nCells,
            'reconciliated': calculateNCellsReconciliatedColumn(table, columnName)
            }}

def getColumnMetadata(metadata):
    """
    Allows retrieving column-level data, particularly
    the entity corresponding to the column, the column types,
    and the match value of the entities in the column

    :metadata: column metadata obtained from the reconciliator
    :return: dictionary containing the different data
    """
    entity = []
    types = []
    for i in range(len(metadata)):
        try:
            if metadata[i]['id'] == ['column', 'index']:
                entity = metadata[i]['metadata']
        except:
            print("No column entity is provided")
        try:
            if metadata[i]['id'] != ['column', 'index']:
                for j in range(len(metadata[i]['metadata'])):
                    if metadata[i]['metadata'][j]['match'] == True:
                        types.append(metadata[i]['metadata'][j]['type'][0])
        except:
            print("No column type is provided")
    matchMetadataValue = True
    for item in entity:
        if item['match'] == False:
            matchMetadataValue = False
    return {'entity': entity, 'type': types, 'matchMetadataValue': matchMetadataValue}

def createMetadataFieldColumn(metadata):
    """
    Allows creating the metadata field for a column, which will
    then be inserted into the general column-level metadata

    :metadata: column-level metadata
    :return: the metadata field at the column level
    """
    return [
        {'id': '',
         'match': getColumnMetadata(metadata)['matchMetadataValue'],
         'score': 0,
         'name':{'value': '', 'uri': ''},
         'entity': getColumnMetadata(metadata)['entity'],
         'property':[],
         'type': getColumnMetadata(metadata)['type']}
    ]

#------------------------------------------------------------------------------
def calculateScoreBoundColumn(table, columnName, reconciliatorResponse):
    allScores = []
    matchValue = True
    rows = table["rows"].keys()
    for row in rows:
        try:
            annotationMeta = table["rows"][row]['cells'][columnName]['annotationMeta']
            if annotationMeta['annotated'] == True:
                allScores.append(annotationMeta['lowestScore'])
                allScores.append(annotationMeta['highestScore'])
            if annotationMeta['match']['value'] == False:
                matchValue = False
        except KeyError:
            print(f"Missing key in cell annotation metadata: 'annotationMeta'")
            print(f"Row: {row}, Column: {columnName}")
            print(f"Cell data: {table['rows'][row]['cells'][columnName]}")
    
    if allScores:
        return {'lowestScore': min(allScores), 'highestScore': max(allScores), 'matchValue': matchValue}
    else:
        print("No valid annotation metadata found for the column.")
        return {'lowestScore': None, 'highestScore': None, 'matchValue': None}

def createAnnotationMetaColumn(annotated, table, columnName, reconciliatorResponse):
    scoreBound = calculateScoreBoundColumn(
        table, columnName, reconciliatorResponse)
    return {'annotated': annotated,
            'match': {'value': scoreBound['matchValue']},
            'lowestScore': scoreBound['lowestScore'],
            'highestScore': scoreBound['highestScore']
            }


def updateMetadataColumn(table, columnName, idReconciliator, metadata, reconciliatorResponse):
    """
    Allows inserting column-level metadata

    :table: table in raw format
    :columnName: name of the column to operate on
    :idReconciliator: ID of the reconciliator used
    :metadata: column-level metadata
    :reconciliatorResponse: response containing reconciliator information
    :return: the table with the new metadata inserted
    """
    # inquire about the different states
    table['columns'][columnName]['status'] = 'pending'
    table['columns'][columnName]['kind'] = "entity"
    table['columns'][columnName]['context'] = createContextColumn(
        table, columnName, idReconciliator, reconciliatorResponse)
    table['columns'][columnName]['metadata'] = createMetadataFieldColumn(
        metadata)
    table['columns'][columnName]['annotationMeta'] = createAnnotationMetaColumn(
        True, table, columnName, reconciliatorResponse)
    return table

def calculateScoreBoundTable(table):
    """
    Calculates the minimum and maximum score obtained in
    the results of the entire table

    :table: the table in raw format
    :return: a dictionary containing the two values
    """
    allScores = []
    reconciliateColumns = [column for column in table['columns'].keys(
    ) if table['columns'][column]['status'] != 'empty']
    for column in reconciliateColumns:
        try:
            if table['columns'][column]['annotationMeta']['annotated'] == True:
                allScores.append(table['columns'][column]
                                 ['annotationMeta']['lowestScore'])
                allScores.append(table['columns'][column]
                                 ['annotationMeta']['highestScore'])
        except:
            print("Missed column annotation metadata")
    try:
        return {'lowestScore': min(allScores), 'highestScore': max(allScores)}
    except:
        return {'lowestScore': 0, 'highestScore': 0}

def calculateNCellsReconciliated(table):
    """
    Calculates the number of reconciled cells within the
    table

    :table: the table in raw format
    :return: the number of reconciled cells
    """
    cellsReconciliated = 0
    columnsName = table['columns'].keys()
    for column in columnsName:
        try:
            contextReconciliator = table['columns'][column]['context'].keys()
            for reconcliator in contextReconciliator:
                cellsReconciliated += int(table['columns'][column]
                                          ['context'][reconcliator]['reconciliated'])
        except:
            cellsReconciliated += 0
    return cellsReconciliated


def updateMetadataTable(table):
    """
    Inserts metadata at the table level

    :table: table in raw format
    :return: the table with the new metadata inserted
    """
    scoreBound = calculateScoreBoundTable(table)
    table['table']['minMetaScore'] = scoreBound['lowestScore']
    table['table']['maxMetaScore'] = scoreBound['highestScore']
    table['table']['nCellsReconciliated'] = calculateNCellsReconciliated(table)
    return table

def reconcile(table, columnName, idReconciliator):
    """
    Reconciles a column with the chosen reconciliator

    :table: the table with the column to reconcile 
    :columnName: the name of the column to reconcile 
    :idReconciliator: ID of the reconciliator to use 
    :return: table with reconciled column
    """
    reconciliatorResponse = getReconciliatorData()
    reconciliator = getReconciliator(idReconciliator, reconciliatorResponse)
    if reconciliator is None:
        print(f"Reconciliator with ID {idReconciliator} not found.")
        return None
    # creating the request
    url = SEMTUI_URI + '/reconciliators' + str(reconciliator['relativeUrl'])
    payload = createReconciliationPayload(table, columnName, idReconciliator)
    response = requests.post(url, json=payload)
    response = json.loads(response.text)
    # inserting data into the table
    metadata = createCellMetadataNameField(response, idReconciliator, reconciliatorResponse)
    table = updateMetadataCells(table, metadata)
    table = updateMetadataColumn(table, columnName, idReconciliator, metadata, reconciliatorResponse)
    table = updateMetadataTable(table)
    return {'raw': table}

# %%
table = table_json
columnName = "City"
idReconciliator = "hereGeoCoords"
Reconciled_data = reconcile(table, columnName, idReconciliator)

# %%
Reconciled_data
# Out:
# {'raw': {'table': {'id': '44',
#    'idDataset': '13',
#    'name': 'JOT_Date_Transformed2',
#    'nCols': 40,
#    'nRows': 18,
#    'nCells': 720,
#    'nCellsReconciliated': 18,
#    'lastModifiedDate': '2024-05-06T09:34:53.131Z',
#    'minMetaScore': 0.91,
#    'maxMetaScore': 1},
#   'columns': {'Fecha_id': {'id': 'Fecha_id',
#     'label': 'Fecha_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cuenta_id': {'id': 'Cuenta_id',
#     'label': 'Cuenta_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Campaña_id': {'id': 'Campaña_id',
#     'label': 'Campaña_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Grupo_id': {'id': 'Grupo_id',
#     'label': 'Grupo_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Keyword_id': {'id': 'Keyword_id',
#     'label': 'Keyword_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'City_id': {'id': 'City_id',
#     'label': 'City_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'State_id': {'id': 'State_id',
#     'label': 'State_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Country_id': {'id': 'Country_id',
#     'label': 'Country_id',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Keyword': {'id': 'Keyword',
#     'label': 'Keyword',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones': {'id': 'Impresiones',
#     'label': 'Impresiones',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks': {'id': 'Clicks',
#     'label': 'Clicks',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc': {'id': 'Cpc',
#     'label': 'Cpc',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'QualityScore': {'id': 'QualityScore',
#     'label': 'QualityScore',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'City': {'id': 'City',
#     'label': 'City',
#     'status': 'pending',
#     'context': {'georss': {'uri': 'http://www.google.com/maps/place/',
#       'total': 18,
#       'reconciliated': 18}},
#     'metadata': [{'id': '',
#       'match': True,
#       'score': 0,
#       'name': {'value': '', 'uri': ''},
#       'entity': [{'id': 'wd:Q29934236',
#         'name': {'value': 'GlobeCoordinate',
#          'uri': 'http://www.google.com/maps/place/Q29934236'},
#         'score': 0,
#         'match': True,
#         'type': []},
#        {'id': 'georss:point',
#         'name': {'value': 'point',
#          'uri': 'http://www.google.com/maps/place/point'},
#         'score': 0,
#         'match': True,
#         'type': []}],
#       'property': [],
#       'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#        {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'}]}],
#     'kind': 'entity',
#     'annotationMeta': {'annotated': True,
#      'match': {'value': True},
#      'lowestScore': 0.91,
#      'highestScore': 1}},
#    'County': {'id': 'County',
#     'label': 'County',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Country': {'id': 'Country',
#     'label': 'Country',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_q1': {'id': 'Impresiones_q1',
#     'label': 'Impresiones_q1',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_q3': {'id': 'Impresiones_q3',
#     'label': 'Impresiones_q3',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_med': {'id': 'Impresiones_med',
#     'label': 'Impresiones_med',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_iqr': {'id': 'Impresiones_iqr',
#     'label': 'Impresiones_iqr',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_max': {'id': 'Impresiones_max',
#     'label': 'Impresiones_max',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Impresiones_min': {'id': 'Impresiones_min',
#     'label': 'Impresiones_min',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_q1': {'id': 'Clicks_q1',
#     'label': 'Clicks_q1',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_q3': {'id': 'Clicks_q3',
#     'label': 'Clicks_q3',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_med': {'id': 'Clicks_med',
#     'label': 'Clicks_med',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_iqr': {'id': 'Clicks_iqr',
#     'label': 'Clicks_iqr',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_max': {'id': 'Clicks_max',
#     'label': 'Clicks_max',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Clicks_min': {'id': 'Clicks_min',
#     'label': 'Clicks_min',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_q1': {'id': 'Cpc_q1',
#     'label': 'Cpc_q1',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_q3': {'id': 'Cpc_q3',
#     'label': 'Cpc_q3',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_med': {'id': 'Cpc_med',
#     'label': 'Cpc_med',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_iqr': {'id': 'Cpc_iqr',
#     'label': 'Cpc_iqr',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_max': {'id': 'Cpc_max',
#     'label': 'Cpc_max',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Cpc_min': {'id': 'Cpc_min',
#     'label': 'Cpc_min',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_q1': {'id': 'Qs_q1',
#     'label': 'Qs_q1',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_q3': {'id': 'Qs_q3',
#     'label': 'Qs_q3',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_med': {'id': 'Qs_med',
#     'label': 'Qs_med',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_iqr': {'id': 'Qs_iqr',
#     'label': 'Qs_iqr',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_max': {'id': 'Qs_max',
#     'label': 'Qs_max',
#     'status': 'empty',
#     'context': {},
#     'metadata': []},
#    'Qs_min': {'id': 'Qs_min',
#     'label': 'Qs_min',
#     'status': 'empty',
#     'context': {},
#     'metadata': []}},
#   'rows': {'r0': {'id': 'r0',
#     'cells': {'Fecha_id': {'id': 'r0$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r0$Cuenta_id',
#       'label': '1018571837',
#       'metadata': []},
#      'Campaña_id': {'id': 'r0$Campaña_id',
#       'label': '17309187968',
#       'metadata': []},
#      'Grupo_id': {'id': 'r0$Grupo_id',
#       'label': '138000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r0$Keyword_id',
#       'label': '299000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r0$City_id', 'label': '1023619', 'metadata': []},
#      'State_id': {'id': 'r0$State_id', 'label': '21168', 'metadata': []},
#      'Country_id': {'id': 'r0$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r0$Keyword',
#       'label': '5th third bank cd rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r0$Impresiones', 'label': '4', 'metadata': []},
#      'Clicks': {'id': 'r0$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r0$Cpc', 'label': '9000000', 'metadata': []},
#      'QualityScore': {'id': 'r0$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r0$City',
#       'label': 'Chardon',
#       'metadata': [{'id': 'georss:41.58339,-81.20288',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Chardon, OH, United States',
#          'uri': 'http://www.google.com/maps/place/41.58339,-81.20288'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r0$County', 'label': 'Ohio', 'metadata': []},
#      'Country': {'id': 'r0$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r0$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r0$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r0$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r0$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r0$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r0$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r0$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r0$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r0$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r0$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r0$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r0$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r0$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r0$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r0$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r0$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r0$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r0$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r0$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r0$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r0$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r0$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r0$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r0$Qs_min', 'label': '0', 'metadata': []}}},
#    'r1': {'id': 'r1',
#     'cells': {'Fecha_id': {'id': 'r1$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r1$Cuenta_id',
#       'label': '1018571837',
#       'metadata': []},
#      'Campaña_id': {'id': 'r1$Campaña_id',
#       'label': '17309187968',
#       'metadata': []},
#      'Grupo_id': {'id': 'r1$Grupo_id',
#       'label': '138000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r1$Keyword_id',
#       'label': '299000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r1$City_id', 'label': '1023631', 'metadata': []},
#      'State_id': {'id': 'r1$State_id', 'label': '21168', 'metadata': []},
#      'Country_id': {'id': 'r1$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r1$Keyword',
#       'label': '5th third bank cd rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r1$Impresiones', 'label': '4', 'metadata': []},
#      'Clicks': {'id': 'r1$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r1$Cpc', 'label': '9000000', 'metadata': []},
#      'QualityScore': {'id': 'r1$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r1$City',
#       'label': 'Cleveland',
#       'metadata': [{'id': 'georss:41.50473,-81.69074',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Cleveland, OH, United States',
#          'uri': 'http://www.google.com/maps/place/41.50473,-81.69074'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r1$County', 'label': 'Ohio', 'metadata': []},
#      'Country': {'id': 'r1$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r1$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r1$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r1$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r1$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r1$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r1$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r1$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r1$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r1$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r1$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r1$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r1$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r1$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r1$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r1$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r1$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r1$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r1$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r1$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r1$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r1$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r1$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r1$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r1$Qs_min', 'label': '0', 'metadata': []}}},
#    'r2': {'id': 'r2',
#     'cells': {'Fecha_id': {'id': 'r2$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r2$Cuenta_id',
#       'label': '1018571837',
#       'metadata': []},
#      'Campaña_id': {'id': 'r2$Campaña_id',
#       'label': '17309187968',
#       'metadata': []},
#      'Grupo_id': {'id': 'r2$Grupo_id',
#       'label': '138000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r2$Keyword_id',
#       'label': '299000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r2$City_id', 'label': '1016367', 'metadata': []},
#      'State_id': {'id': 'r2$State_id', 'label': '21147', 'metadata': []},
#      'Country_id': {'id': 'r2$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r2$Keyword',
#       'label': '5th third bank cd rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r2$Impresiones', 'label': '5', 'metadata': []},
#      'Clicks': {'id': 'r2$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r2$Cpc', 'label': '9000000', 'metadata': []},
#      'QualityScore': {'id': 'r2$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r2$City',
#       'label': 'Chicago',
#       'metadata': [{'id': 'georss:41.88425,-87.63245',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Chicago, IL, United States',
#          'uri': 'http://www.google.com/maps/place/41.88425,-87.63245'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r2$County', 'label': 'Illinois', 'metadata': []},
#      'Country': {'id': 'r2$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r2$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r2$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r2$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r2$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r2$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r2$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r2$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r2$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r2$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r2$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r2$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r2$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r2$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r2$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r2$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r2$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r2$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r2$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r2$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r2$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r2$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r2$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r2$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r2$Qs_min', 'label': '0', 'metadata': []}}},
#    'r3': {'id': 'r3',
#     'cells': {'Fecha_id': {'id': 'r3$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r3$Cuenta_id',
#       'label': '1018571837',
#       'metadata': []},
#      'Campaña_id': {'id': 'r3$Campaña_id',
#       'label': '17309187968',
#       'metadata': []},
#      'Grupo_id': {'id': 'r3$Grupo_id',
#       'label': '138000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r3$Keyword_id',
#       'label': '299000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r3$City_id', 'label': '1027744', 'metadata': []},
#      'State_id': {'id': 'r3$State_id', 'label': '21180', 'metadata': []},
#      'Country_id': {'id': 'r3$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r3$Keyword',
#       'label': '5th third bank cd rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r3$Impresiones', 'label': '4', 'metadata': []},
#      'Clicks': {'id': 'r3$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r3$Cpc', 'label': '9000000', 'metadata': []},
#      'QualityScore': {'id': 'r3$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r3$City',
#       'label': 'Seattle',
#       'metadata': [{'id': 'georss:47.60357,-122.32945',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Seattle, WA, United States',
#          'uri': 'http://www.google.com/maps/place/47.60357,-122.32945'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r3$County', 'label': 'Washington', 'metadata': []},
#      'Country': {'id': 'r3$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r3$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r3$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r3$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r3$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r3$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r3$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r3$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r3$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r3$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r3$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r3$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r3$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r3$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r3$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r3$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r3$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r3$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r3$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r3$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r3$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r3$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r3$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r3$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r3$Qs_min', 'label': '0', 'metadata': []}}},
#    'r4': {'id': 'r4',
#     'cells': {'Fecha_id': {'id': 'r4$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r4$Cuenta_id',
#       'label': '1119272776',
#       'metadata': []},
#      'Campaña_id': {'id': 'r4$Campaña_id',
#       'label': '20325090181',
#       'metadata': []},
#      'Grupo_id': {'id': 'r4$Grupo_id',
#       'label': '154000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r4$Keyword_id',
#       'label': '2240000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r4$City_id', 'label': '1016359', 'metadata': []},
#      'State_id': {'id': 'r4$State_id', 'label': '21147', 'metadata': []},
#      'Country_id': {'id': 'r4$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r4$Keyword',
#       'label': 'p n c bank c d rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r4$Impresiones', 'label': '3', 'metadata': []},
#      'Clicks': {'id': 'r4$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r4$Cpc', 'label': '6130000', 'metadata': []},
#      'QualityScore': {'id': 'r4$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r4$City',
#       'label': 'Champaign',
#       'metadata': [{'id': 'georss:40.1142,-88.2435',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Champaign, IL, United States',
#          'uri': 'http://www.google.com/maps/place/40.1142,-88.2435'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r4$County', 'label': 'Illinois', 'metadata': []},
#      'Country': {'id': 'r4$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r4$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r4$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r4$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r4$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r4$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r4$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r4$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r4$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r4$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r4$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r4$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r4$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r4$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r4$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r4$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r4$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r4$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r4$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r4$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r4$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r4$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r4$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r4$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r4$Qs_min', 'label': '0', 'metadata': []}}},
#    'r5': {'id': 'r5',
#     'cells': {'Fecha_id': {'id': 'r5$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r5$Cuenta_id',
#       'label': '1119272776',
#       'metadata': []},
#      'Campaña_id': {'id': 'r5$Campaña_id',
#       'label': '20325090181',
#       'metadata': []},
#      'Grupo_id': {'id': 'r5$Grupo_id',
#       'label': '154000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r5$Keyword_id',
#       'label': '2240000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r5$City_id', 'label': '1023815', 'metadata': []},
#      'State_id': {'id': 'r5$State_id', 'label': '21168', 'metadata': []},
#      'Country_id': {'id': 'r5$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r5$Keyword',
#       'label': 'p n c bank c d rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r5$Impresiones', 'label': '3', 'metadata': []},
#      'Clicks': {'id': 'r5$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r5$Cpc', 'label': '6130000', 'metadata': []},
#      'QualityScore': {'id': 'r5$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r5$City',
#       'label': 'Marion',
#       'metadata': [{'id': 'georss:40.55881,-85.66067',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, IN, United States',
#          'uri': 'http://www.google.com/maps/place/40.55881,-85.66067'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:40.58382,-83.12852',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, OH, United States',
#          'uri': 'http://www.google.com/maps/place/40.58382,-83.12852'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:35.68431,-82.00838',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, NC, United States',
#          'uri': 'http://www.google.com/maps/place/35.68431,-82.00838'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:42.03331,-91.59961',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, IA, United States',
#          'uri': 'http://www.google.com/maps/place/42.03331,-91.59961'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:37.73082,-88.93004',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, IL, United States',
#          'uri': 'http://www.google.com/maps/place/37.73082,-88.93004'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:35.21846,-90.19955',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, AR, United States',
#          'uri': 'http://www.google.com/maps/place/35.21846,-90.19955'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:36.83398,-81.51734',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, VA, United States',
#          'uri': 'http://www.google.com/maps/place/36.83398,-81.51734'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:34.17807,-79.4004',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, SC, United States',
#          'uri': 'http://www.google.com/maps/place/34.17807,-79.4004'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:29.5716,-98.13881',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, TX, United States',
#          'uri': 'http://www.google.com/maps/place/29.5716,-98.13881'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:44.67129,-88.88927',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, WI, United States',
#          'uri': 'http://www.google.com/maps/place/44.67129,-88.88927'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:37.33224,-88.08144',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, KY, United States',
#          'uri': 'http://www.google.com/maps/place/37.33224,-88.08144'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:41.70309,-70.76263',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, MA, United States',
#          'uri': 'http://www.google.com/maps/place/41.70309,-70.76263'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.1429,-77.18927',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, NY, United States',
#          'uri': 'http://www.google.com/maps/place/43.1429,-77.18927'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:32.63467,-87.31913',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, AL, United States',
#          'uri': 'http://www.google.com/maps/place/32.63467,-87.31913'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:48.09847,-114.64972',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, MT, United States',
#          'uri': 'http://www.google.com/maps/place/48.09847,-114.64972'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:38.34816,-97.02147',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, KS, United States',
#          'uri': 'http://www.google.com/maps/place/38.34816,-97.02147'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:44.10296,-85.14743',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, MI, United States',
#          'uri': 'http://www.google.com/maps/place/44.10296,-85.14743'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:32.42001,-88.65128',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, MS, United States',
#          'uri': 'http://www.google.com/maps/place/32.42001,-88.65128'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.42625,-97.26073',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion, SD, United States',
#          'uri': 'http://www.google.com/maps/place/43.42625,-97.26073'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:45.27883,-85.27118',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Marion Twp, MI, United States',
#          'uri': 'http://www.google.com/maps/place/45.27883,-85.27118'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r5$County', 'label': 'Ohio', 'metadata': []},
#      'Country': {'id': 'r5$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r5$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r5$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r5$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r5$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r5$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r5$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r5$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r5$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r5$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r5$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r5$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r5$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r5$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r5$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r5$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r5$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r5$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r5$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r5$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r5$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r5$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r5$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r5$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r5$Qs_min', 'label': '0', 'metadata': []}}},
#    'r6': {'id': 'r6',
#     'cells': {'Fecha_id': {'id': 'r6$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r6$Cuenta_id',
#       'label': '1119272776',
#       'metadata': []},
#      'Campaña_id': {'id': 'r6$Campaña_id',
#       'label': '20325090181',
#       'metadata': []},
#      'Grupo_id': {'id': 'r6$Grupo_id',
#       'label': '154000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r6$Keyword_id',
#       'label': '2240000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r6$City_id', 'label': '1025531', 'metadata': []},
#      'State_id': {'id': 'r6$State_id', 'label': '21173', 'metadata': []},
#      'Country_id': {'id': 'r6$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r6$Keyword',
#       'label': 'p n c bank c d rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r6$Impresiones', 'label': '3', 'metadata': []},
#      'Clicks': {'id': 'r6$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r6$Cpc', 'label': '6130000', 'metadata': []},
#      'QualityScore': {'id': 'r6$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r6$City',
#       'label': 'Conway',
#       'metadata': [{'id': 'georss:35.09098,-92.43969',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, AR, United States',
#          'uri': 'http://www.google.com/maps/place/35.09098,-92.43969'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:33.83473,-79.05036',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, SC, United States',
#          'uri': 'http://www.google.com/maps/place/33.83473,-79.05036'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.97981,-71.10824',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, NH, United States',
#          'uri': 'http://www.google.com/maps/place/43.97981,-71.10824'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:42.5096,-72.69973',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, MA, United States',
#          'uri': 'http://www.google.com/maps/place/42.5096,-72.69973'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:37.50211,-92.82165',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, MO, United States',
#          'uri': 'http://www.google.com/maps/place/37.50211,-92.82165'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:48.23394,-97.6753',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, ND, United States',
#          'uri': 'http://www.google.com/maps/place/48.23394,-97.6753'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:40.74927,-94.6189',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, IA, United States',
#          'uri': 'http://www.google.com/maps/place/40.74927,-94.6189'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:40.66176,-80.23792',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, PA, United States',
#          'uri': 'http://www.google.com/maps/place/40.66176,-80.23792'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:36.43709,-77.22957',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, NC, United States',
#          'uri': 'http://www.google.com/maps/place/36.43709,-77.22957'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:48.34129,-122.34526',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, WA, United States',
#          'uri': 'http://www.google.com/maps/place/48.34129,-122.34526'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:45.42115,-84.86313',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, MI, United States',
#          'uri': 'http://www.google.com/maps/place/45.42115,-84.86313'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:-20.47189,148.73401',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Conway, QLD 4800, Australia',
#          'uri': 'http://www.google.com/maps/place/-20.47189,148.73401'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r6$County', 'label': 'South Carolina', 'metadata': []},
#      'Country': {'id': 'r6$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r6$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r6$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r6$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r6$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r6$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r6$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r6$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r6$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r6$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r6$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r6$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r6$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r6$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r6$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r6$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r6$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r6$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r6$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r6$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r6$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r6$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r6$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r6$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r6$Qs_min', 'label': '0', 'metadata': []}}},
#    'r7': {'id': 'r7',
#     'cells': {'Fecha_id': {'id': 'r7$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r7$Cuenta_id',
#       'label': '1119272776',
#       'metadata': []},
#      'Campaña_id': {'id': 'r7$Campaña_id',
#       'label': '20325090181',
#       'metadata': []},
#      'Grupo_id': {'id': 'r7$Grupo_id',
#       'label': '154000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r7$Keyword_id',
#       'label': '2240000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r7$City_id', 'label': '1026730', 'metadata': []},
#      'State_id': {'id': 'r7$State_id', 'label': '21176', 'metadata': []},
#      'Country_id': {'id': 'r7$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r7$Keyword',
#       'label': 'p n c bank c d rates',
#       'metadata': []},
#      'Impresiones': {'id': 'r7$Impresiones', 'label': '2', 'metadata': []},
#      'Clicks': {'id': 'r7$Clicks', 'label': '5', 'metadata': []},
#      'Cpc': {'id': 'r7$Cpc', 'label': '6130000', 'metadata': []},
#      'QualityScore': {'id': 'r7$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r7$City',
#       'label': 'Richmond',
#       'metadata': [{'id': 'georss:37.54068,-77.43367',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Richmond, VA, United States',
#          'uri': 'http://www.google.com/maps/place/37.54068,-77.43367'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r7$County', 'label': 'Texas', 'metadata': []},
#      'Country': {'id': 'r7$Country', 'label': 'United States', 'metadata': []},
#      'Impresiones_q1': {'id': 'r7$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r7$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r7$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r7$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r7$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r7$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r7$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r7$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r7$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r7$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r7$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r7$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r7$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r7$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r7$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r7$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r7$Cpc_max', 'label': '999000000', 'metadata': []},
# ...
#       'metadata': [{'id': 'georss:34.87558,-76.90345',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Havelock, NC, United States',
#          'uri': 'http://www.google.com/maps/place/34.87558,-76.90345'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:45.04412,-73.75806',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Havelock, QC, Canada',
#          'uri': 'http://www.google.com/maps/place/45.04412,-73.75806'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:-41.281,173.76715',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Havelock, Marlborough, New Zealand',
#          'uri': 'http://www.google.com/maps/place/-41.281,173.76715'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:42.83483,-94.70171',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Havelock, IA, United States',
#          'uri': 'http://www.google.com/maps/place/42.83483,-94.70171'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:-36.96529,143.77288',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Havelock, VIC 3465, Australia',
#          'uri': 'http://www.google.com/maps/place/-36.96529,143.77288'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r15$County', 'label': 'North Carolina', 'metadata': []},
#      'Country': {'id': 'r15$Country',
#       'label': 'United States',
#       'metadata': []},
#      'Impresiones_q1': {'id': 'r15$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r15$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r15$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r15$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r15$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r15$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r15$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r15$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r15$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r15$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r15$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r15$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r15$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r15$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r15$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r15$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r15$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r15$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r15$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r15$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r15$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r15$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r15$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r15$Qs_min', 'label': '0', 'metadata': []}}},
#    'r16': {'id': 'r16',
#     'cells': {'Fecha_id': {'id': 'r16$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r16$Cuenta_id',
#       'label': '1150766542',
#       'metadata': []},
#      'Campaña_id': {'id': 'r16$Campaña_id',
#       'label': '18850329589',
#       'metadata': []},
#      'Grupo_id': {'id': 'r16$Grupo_id',
#       'label': '148000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r16$Keyword_id',
#       'label': '352000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r16$City_id', 'label': '9052608', 'metadata': []},
#      'State_id': {'id': 'r16$State_id', 'label': '21136', 'metadata': []},
#      'Country_id': {'id': 'r16$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r16$Keyword',
#       'label': 'armed forces recruiting',
#       'metadata': []},
#      'Impresiones': {'id': 'r16$Impresiones', 'label': '4', 'metadata': []},
#      'Clicks': {'id': 'r16$Clicks', 'label': '4', 'metadata': []},
#      'Cpc': {'id': 'r16$Cpc', 'label': '6900000', 'metadata': []},
#      'QualityScore': {'id': 'r16$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r16$City',
#       'label': 'Oro Valley',
#       'metadata': [{'id': 'georss:32.4078,-110.99569',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Oro Valley, AZ, United States',
#          'uri': 'http://www.google.com/maps/place/32.4078,-110.99569'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r16$County', 'label': 'Arizona', 'metadata': []},
#      'Country': {'id': 'r16$Country',
#       'label': 'United States',
#       'metadata': []},
#      'Impresiones_q1': {'id': 'r16$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r16$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r16$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r16$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r16$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r16$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r16$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r16$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r16$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r16$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r16$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r16$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r16$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r16$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r16$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r16$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r16$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r16$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r16$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r16$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r16$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r16$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r16$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r16$Qs_min', 'label': '0', 'metadata': []}}},
#    'r17': {'id': 'r17',
#     'cells': {'Fecha_id': {'id': 'r17$Fecha_id',
#       'label': '2023-07-01',
#       'metadata': []},
#      'Cuenta_id': {'id': 'r17$Cuenta_id',
#       'label': '1333143884',
#       'metadata': []},
#      'Campaña_id': {'id': 'r17$Campaña_id',
#       'label': '20071681157',
#       'metadata': []},
#      'Grupo_id': {'id': 'r17$Grupo_id',
#       'label': '148000000000.0',
#       'metadata': []},
#      'Keyword_id': {'id': 'r17$Keyword_id',
#       'label': '352000000000.0',
#       'metadata': []},
#      'City_id': {'id': 'r17$City_id', 'label': '1014964', 'metadata': []},
#      'State_id': {'id': 'r17$State_id', 'label': '21142', 'metadata': []},
#      'Country_id': {'id': 'r17$Country_id', 'label': '2840', 'metadata': []},
#      'Keyword': {'id': 'r17$Keyword',
#       'label': 'armed forces recruiting',
#       'metadata': []},
#      'Impresiones': {'id': 'r17$Impresiones', 'label': '39', 'metadata': []},
#      'Clicks': {'id': 'r17$Clicks', 'label': '0', 'metadata': []},
#      'Cpc': {'id': 'r17$Cpc', 'label': '20000', 'metadata': []},
#      'QualityScore': {'id': 'r17$QualityScore', 'label': '', 'metadata': []},
#      'City': {'id': 'r17$City',
#       'label': 'Brandon',
#       'metadata': [{'id': 'georss:49.84937,-99.96192',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, MB, Canada',
#          'uri': 'http://www.google.com/maps/place/49.84937,-99.96192'},
#         'score': 1,
#         'match': True,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:27.94015,-82.32543',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, FL, United States',
#          'uri': 'http://www.google.com/maps/place/27.94015,-82.32543'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:52.44274,0.62621',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, England, United Kingdom',
#          'uri': 'http://www.google.com/maps/place/52.44274,0.62621'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:32.27313,-89.98891',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, MS, United States',
#          'uri': 'http://www.google.com/maps/place/32.27313,-89.98891'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.80005,-73.09263',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, VT, United States',
#          'uri': 'http://www.google.com/maps/place/43.80005,-73.09263'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.59441,-96.57235',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, SD, United States',
#          'uri': 'http://www.google.com/maps/place/43.59441,-96.57235'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:-19.55431,147.35412',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, QLD 4808, Australia',
#          'uri': 'http://www.google.com/maps/place/-19.55431,147.35412'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:45.96393,-95.59951',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, MN, United States',
#          'uri': 'http://www.google.com/maps/place/45.96393,-95.59951'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:44.76241,-74.42118',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, NY, United States',
#          'uri': 'http://www.google.com/maps/place/44.76241,-74.42118'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:42.3145,-92.00643',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, IA, United States',
#          'uri': 'http://www.google.com/maps/place/42.3145,-92.00643'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:43.73449,-88.77773',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brandon, WI, United States',
#          'uri': 'http://www.google.com/maps/place/43.73449,-88.77773'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]},
#        {'id': 'georss:65.6967,22.33465',
#         'feature': [{'id': 'all_labels', 'value': 100}],
#         'name': {'value': 'Brändön, Norrbotten County, Sweden',
#          'uri': 'http://www.google.com/maps/place/65.6967,22.33465'},
#         'score': 1,
#         'match': False,
#         'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#          {'id': 'georss:point', 'name': 'point'}]}],
#       'annotationMeta': {'annotated': True,
#        'match': {'value': True},
#        'lowestScore': 1,
#        'highestScore': 1}},
#      'County': {'id': 'r17$County', 'label': 'Florida', 'metadata': []},
#      'Country': {'id': 'r17$Country',
#       'label': 'United States',
#       'metadata': []},
#      'Impresiones_q1': {'id': 'r17$Impresiones_q1',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_q3': {'id': 'r17$Impresiones_q3',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_med': {'id': 'r17$Impresiones_med',
#       'label': '1',
#       'metadata': []},
#      'Impresiones_iqr': {'id': 'r17$Impresiones_iqr',
#       'label': '0',
#       'metadata': []},
#      'Impresiones_max': {'id': 'r17$Impresiones_max',
#       'label': '2794',
#       'metadata': []},
#      'Impresiones_min': {'id': 'r17$Impresiones_min',
#       'label': '0',
#       'metadata': []},
#      'Clicks_q1': {'id': 'r17$Clicks_q1', 'label': '0', 'metadata': []},
#      'Clicks_q3': {'id': 'r17$Clicks_q3', 'label': '0', 'metadata': []},
#      'Clicks_med': {'id': 'r17$Clicks_med', 'label': '0', 'metadata': []},
#      'Clicks_iqr': {'id': 'r17$Clicks_iqr', 'label': '0', 'metadata': []},
#      'Clicks_max': {'id': 'r17$Clicks_max', 'label': '148', 'metadata': []},
#      'Clicks_min': {'id': 'r17$Clicks_min', 'label': '0', 'metadata': []},
#      'Cpc_q1': {'id': 'r17$Cpc_q1', 'label': '160000', 'metadata': []},
#      'Cpc_q3': {'id': 'r17$Cpc_q3', 'label': '620000', 'metadata': []},
#      'Cpc_med': {'id': 'r17$Cpc_med', 'label': '300000', 'metadata': []},
#      'Cpc_iqr': {'id': 'r17$Cpc_iqr', 'label': '460000', 'metadata': []},
#      'Cpc_max': {'id': 'r17$Cpc_max', 'label': '999000000', 'metadata': []},
#      'Cpc_min': {'id': 'r17$Cpc_min', 'label': '10000', 'metadata': []},
#      'Qs_q1': {'id': 'r17$Qs_q1', 'label': '0', 'metadata': []},
#      'Qs_q3': {'id': 'r17$Qs_q3', 'label': '0', 'metadata': []},
#      'Qs_med': {'id': 'r17$Qs_med', 'label': '0', 'metadata': []},
#      'Qs_iqr': {'id': 'r17$Qs_iqr', 'label': '0', 'metadata': []},
#      'Qs_max': {'id': 'r17$Qs_max', 'label': '10', 'metadata': []},
#      'Qs_min': {'id': 'r17$Qs_min', 'label': '0', 'metadata': []}}}}}}

# %%
############### 2nd method reconciliation #################

import requests
from requests.exceptions import RequestException


def getExtender(idExtender, response):
    """
    Given the extender's ID, returns the main information in JSON format

    :idExtender: the ID of the extender in question
    :response: JSON containing information about the extenders
    :return: JSON containing the main information of the extender
    """
    for extender in response:
        if extender['id'] == idExtender:
            return {
                'name': extender['name'],
                'relativeUrl': extender['relativeUrl']
            }
    return None

def createExtensionPayload(data, reconciliatedColumnName, properties, idExtender, dates=None):
    """
    Creates the payload for the extension request

    :param data: table in raw format
    :param reconciliatedColumnName: the name of the column containing reconciled id
    :param properties: the properties to use in a list format
    :param idExtender: the ID of the extender service
    :param dates: (optional) a dictionary containing date information for each row (specific to openMeteoExtender)
    :return: the request payload
    """
    items = {}
    if 'rows' not in data:
        raise KeyError("The 'data' dictionary does not contain the 'rows'")
    rows = data['rows'].keys()
    for row in rows:
        if 'cells' not in data['rows'][row]:
            raise KeyError(f"The 'data['rows'][{row}]' dictionary does not contain the 'cells' key.")
        
        cell = data['rows'][row]['cells'].get(reconciliatedColumnName)
        if cell and cell.get('annotationMeta', {}).get('match', {}).get('value') == True:
            for metadata in cell.get('metadata', []):
                if metadata.get('match') == True:
                    items[row] = metadata.get('id')
                    break    
    payload = {
        "serviceId": idExtender,
        "items": {
            str(reconciliatedColumnName): items
        },
        "property": properties
    }
    
    if idExtender == "openMeteoExtender":
        if dates is None:
            raise ValueError("The 'dates' parameter is required for the openMeteoExtender.")
        payload["dates"] = dates
        payload["weatherParams"] = properties  # This can be customized if needed
        payload["decimalFormat"] = []  # This can be customized or set externally if needed
    
    return payload

def getReconciliatorFromPrefix(prefixReconciliator, response):
    """
    Function that, given the reconciliator's prefix, returns a dictionary 
    with all the service information

    :prefixReconciliator: the prefix of the reconciliator in question
    :return: a dictionary with the reconciliator's information
    """
    for reconciliator in response:
        if reconciliator['prefix'] == prefixReconciliator:
            return {
                'uri': reconciliator['uri'],
                'id': reconciliator['id'],
                'name': reconciliator['name'],
                'relativeUrl': reconciliator['relativeUrl']
            }
    return None

def getColumnIdReconciliator(table, columnName, reconciliatorResponse):
    """
    Specifying the column of interest returns the reconciliator's ID,
    if the column is reconciled

    :table: table in raw format
    :columnName: name of the column in question
    :return: the ID of the reconciliator used
    """
    prefix = list(table['columns'][columnName]['context'].keys())
    return getReconciliatorFromPrefix(prefix[0], reconciliatorResponse)['id']

def checkEntity(newColumnData):
    entity = False
    # Assuming newColumnData refers to a row payload, which contains a 'cells' list
    for cell in newColumnData['cells']:
        # Check if there is metadata and it's not empty
        if 'metadata' in cell and cell['metadata']:
            entity = True
            break
    return entity


def parseNameEntities(entities, uriReconciliator):
    """
    Function iterated in parseNameMetadata, works at the entity level

    :param entities: List of entities present in the cell/column
    :param uriReconciliator: the URI of the affiliated knowledge graph
    :return: List of entities with updated names
    """
    for entity in entities:
        if 'id' in entity and ':' in entity['id']:
            entity_type = entity['id'].split(':')[1]  # Safely extract after colon
            entity['name'] = parseNameField(
                entity.get('name', ''),  # Safely access 'name'
                uriReconciliator,
                entity_type
            )
    return entities

def addExtendedCell(table, newColumnData, newColumnName, idReconciliator, reconciliatorResponse):
    if 'cells' not in newColumnData:
        raise ValueError("newColumnData must contain 'cells'")
    
    rowKeys = newColumnData['cells']
    entity = checkEntity(newColumnData)
    columnType = newColumnData.get('kind', 'entity' if entity else 'literal')

    for rowKey in rowKeys:
        cellData = newColumnData['cells'][rowKey]
        newCell = table['rows'][rowKey]['cells'].setdefault(newColumnName, {})
        newCell['id'] = f"{rowKey}${newColumnName}"
        newCell['label'] = cellData.get('label', '')

        uriReconciliator = getReconciliator(idReconciliator, reconciliatorResponse)['uri']
        newCell['metadata'] = parseNameEntities(cellData.get('metadata', []), uriReconciliator)

        if columnType == 'entity':
            newCell['annotationMeta'] = createAnnotationMetaCell(newCell['metadata'])
        else:
            newCell['annotationMeta'] = {}

    return table

def addExtendedColumns(table, extensionData, newColumnsName, reconciliatorResponse):
    """
    Allows iterating the operations to insert a single column for
    all the properties to be inserted.

    :param table: table in raw format
    :param extensionData: data obtained from the extender
    :param newColumnsName: names of the new columns to insert into the table
    :param reconciliatorResponse: response containing reconciliator information
    :return: the table with the new fields inserted
    """
    if 'columns' not in extensionData or 'meta' not in extensionData:
        raise ValueError("extensionData must contain 'columns' and 'meta'")

    # Iterating through new columns to be added
    for i, columnKey in enumerate(extensionData['columns'].keys()):
        if i >= len(newColumnsName):
            raise IndexError("There are more columns to add than names provided.")
        
        # Fetching reconciliator ID for the current column
        idReconciliator = getColumnIdReconciliator(
            table, extensionData['meta'][columnKey], reconciliatorResponse)
        
        # Adding the extended cell/column to the table
        table = addExtendedCell(
            table, extensionData['columns'][columnKey], newColumnsName[i], idReconciliator, reconciliatorResponse)
        
    return table

def parseNameMetadata(metadata, uriReconciliator):
    if not isinstance(metadata, list):
        raise ValueError("Expected metadata to be a list")
    
    for item in metadata:
        if 'entity' in item:
            try:
                item['entity'] = parseNameEntities(item['entity'], uriReconciliator)
            except KeyError as e:
                raise KeyError(f"Missing expected key in entity data: {str(e)}")
            except Exception as e:
                raise Exception(f"An error occurred while parsing entities: {str(e)}")
        else:
            raise KeyError("Expected 'entity' key in each metadata item")

    return metadata

def addExtendedColumns(table, extensionData, newColumnsName, reconciliatorResponse):
    if 'columns' not in extensionData or 'meta' not in extensionData:
        raise ValueError("extensionData must contain 'columns' and 'meta'")

    for i, columnKey in enumerate(extensionData['columns'].keys()):
        if i >= len(newColumnsName):
            raise IndexError("There are more columns to add than names provided.")
        
        idReconciliator = getColumnIdReconciliator(
            table, extensionData['meta'][columnKey], reconciliatorResponse)
        
        table = addExtendedCell(
            table, extensionData['columns'][columnKey], newColumnsName[i], idReconciliator, reconciliatorResponse)
        
    return table

def extendColumn(table, reconciliatedColumnName, idExtender, properties, newColumnsName, dateColumnName):
    """
    Allows extending specified properties present in the Knowledge Graph as a new column.

    :param table: the table containing the data
    :param reconciliatedColumnName: the column containing the ID in the KG
    :param idExtender: the extender to use for extension
    :param properties: the properties to extend in the table
    :param newColumnsName: the name of the new columns to add
    :param dateColumnName: the name of the date column to extract date information for each row
    :return: the extended table
    """
    # Prepare the dates information dynamically
    dates = {}
    for row_key, row_data in table['rows'].items():
        # Safely extract date_value from the label key of the date column
        date_value = row_data['cells'].get(dateColumnName, {}).get('label')
        
        if date_value:
            dates[row_key] = [date_value]
        else:
            print(f"Missing or invalid date for row {row_key}, skipping this row.")
            continue  # Optionally skip this row or handle accordingly

    reconciliatorResponse = getReconciliatorData()
    extenderData = getExtender(idExtender, getExtenderData())
    url = SEMTUI_URI + "extenders/" + extenderData['relativeUrl']
    payload = createExtensionPayload(table, reconciliatedColumnName, properties, idExtender, dates)
    headers = {"Accept": "application/json"}
    try:
        response = requests.post(url, json=payload, headers=headers)
        print(f"HTTP Status Code: {response.status_code}")
        print(f"HTTP Response Text: '{response.text}'")
        response.raise_for_status()
        data = response.json()
        table = addExtendedColumns(table, data, newColumnsName, reconciliatorResponse)
        return table
    except requests.RequestException as e:
        print(f"Network-related error occurred: {e}")
    except json.JSONDecodeError as e:
        print("Error parsing JSON response:", e)
        print("Raw response for debugging:", response.text)
    except KeyError as e:
        print(f"Missing expected key in data:", e)

# %%
# Usage example assuming other function dependencies are properly defined and available
update_payload = Reconciled_data  # Assuming 'result' is defined elsewhere
reconciliatedColumnName = "City"
idExtender = "openMeteoExtender"  # ID for Open Meteo Properties extender
properties = ["apparent_temperature_max", "apparent_temperature_min", "precipitation_sum"]
newColumnsName = ["apparent_temperature_max", "apparent_temperature_min", "precipitation_sum"]
dateColumnName = "Fecha_id"  # Column name for the date

New_data = extendColumn(update_payload['raw'], reconciliatedColumnName, idExtender, properties, newColumnsName, dateColumnName)
# Out:
# HTTP Status Code: 200
# HTTP Response Text: '{"columns":{"City_apparent_temperature_max":{"label":"City_apparent_temperature_max","metadata":[],"cells":{"r0":{"label":"29,9","metadata":[]},"r1":{"label":"30,7","metadata":[]},"r2":{"label":"32,4","metadata":[]},"r3":{"label":"25","metadata":[]},"r4":{"label":"34,9","metadata":[]},"r5":{"label":"32,2","metadata":[]},"r6":{"label":"40,1","metadata":[]},"r7":{"label":"36,5","metadata":[]},"r8":{"label":"27,5","metadata":[]},"r9":{"label":"42,2","metadata":[]},"r10":{"label":"41,6","metadata":[]},"r11":{"label":"41,4","metadata":[]},"r12":{"label":"23,9","metadata":[]},"r13":{"label":"31,9","metadata":[]},"r14":{"label":"17,7","metadata":[]},"r15":{"label":"37","metadata":[]},"r16":{"label":"36,1","metadata":[]},"r17":{"label":"30,2","metadata":[]}}},"City_apparent_temperature_min":{"label":"City_apparent_temperature_min","metadata":[],"cells":{"r0":{"label":"20,3","metadata":[]},"r1":{"label":"22,4","metadata":[]},"r2":{"label":"22,8","metadata":[]},"r3":{"label":"11,3","metadata":[]},"r4":{"label":"23,1","metadata":[]},"r5":{"label":"22,6","metadata":[]},"r6":{"label":"29,8","metadata":[]},"r7":{"label":"21,9","metadata":[]},"r8":{"label":"19,4","metadata":[]},"r9":{"label":"31,3","metadata":[]},"r10":{"label":"19,8","metadata":[]},"r11":{"label":"26","metadata":[]},"r12":{"label":"11,2","metadata":[]},"r13":{"label":"21,1","metadata":[]},"r14":{"label":"14,2","metadata":[]},"r15":{"label":"24,7","metadata":[]},"r16":{"label":"22,2","metadata":[]},"r17":{"label":"16","metadata":[]}}},"City_precipitation_sum":{"label":"City_precipitation_sum","metadata":[],"cells":{"r0":{"label":"10,6","metadata":[]},"r1":{"label":"5,1","metadata":[]},"r2":{"label":"16,2","metadata":[]},"r3":{"label":"0","metadata":[]},"r4":{"label":"12,2","metadata":[]},"r5":{"label":"4,3","metadata":[]},"r6":{"label":"4,4","metadata":[]},"r7":{"label":"1,7","metadata":[]},"r8":{"label":"0","metadata":[]},"r9":{"label":"0","metadata":[]},"r10":{"label":"0","metadata":[]},"r11":{"label":"9,1","metadata":[]},"r12":{"label":"0","metadata":[]},"r13":{"label":"2,4","metadata":[]},"r14":{"label":"5,9","metadata":[]},"r15":{"label":"0,1","metadata":[]},"r16":{"label":"0","metadata":[]},"r17":{"label":"0","metadata":[]}}}},"meta":{"City_apparent_temperature_max":"City","City_apparent_temperature_min":"City","City_precipitation_sum":"City"}}'

# %%
New_data
# Out:
# {'table': {'id': '44',
#   'idDataset': '13',
#   'name': 'JOT_Date_Transformed2',
#   'nCols': 40,
#   'nRows': 18,
#   'nCells': 720,
#   'nCellsReconciliated': 18,
#   'lastModifiedDate': '2024-05-06T09:34:53.131Z',
#   'minMetaScore': 0.91,
#   'maxMetaScore': 1},
#  'columns': {'Fecha_id': {'id': 'Fecha_id',
#    'label': 'Fecha_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cuenta_id': {'id': 'Cuenta_id',
#    'label': 'Cuenta_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Campaña_id': {'id': 'Campaña_id',
#    'label': 'Campaña_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Grupo_id': {'id': 'Grupo_id',
#    'label': 'Grupo_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Keyword_id': {'id': 'Keyword_id',
#    'label': 'Keyword_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'City_id': {'id': 'City_id',
#    'label': 'City_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'State_id': {'id': 'State_id',
#    'label': 'State_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Country_id': {'id': 'Country_id',
#    'label': 'Country_id',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Keyword': {'id': 'Keyword',
#    'label': 'Keyword',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones': {'id': 'Impresiones',
#    'label': 'Impresiones',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks': {'id': 'Clicks',
#    'label': 'Clicks',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc': {'id': 'Cpc',
#    'label': 'Cpc',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'QualityScore': {'id': 'QualityScore',
#    'label': 'QualityScore',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'City': {'id': 'City',
#    'label': 'City',
#    'status': 'pending',
#    'context': {'georss': {'uri': 'http://www.google.com/maps/place/',
#      'total': 18,
#      'reconciliated': 18}},
#    'metadata': [{'id': '',
#      'match': True,
#      'score': 0,
#      'name': {'value': '', 'uri': ''},
#      'entity': [{'id': 'wd:Q29934236',
#        'name': {'value': 'GlobeCoordinate',
#         'uri': 'http://www.google.com/maps/place/Q29934236'},
#        'score': 0,
#        'match': True,
#        'type': []},
#       {'id': 'georss:point',
#        'name': {'value': 'point',
#         'uri': 'http://www.google.com/maps/place/point'},
#        'score': 0,
#        'match': True,
#        'type': []}],
#      'property': [],
#      'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#       {'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'}]}],
#    'kind': 'entity',
#    'annotationMeta': {'annotated': True,
#     'match': {'value': True},
#     'lowestScore': 0.91,
#     'highestScore': 1}},
#   'County': {'id': 'County',
#    'label': 'County',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Country': {'id': 'Country',
#    'label': 'Country',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_q1': {'id': 'Impresiones_q1',
#    'label': 'Impresiones_q1',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_q3': {'id': 'Impresiones_q3',
#    'label': 'Impresiones_q3',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_med': {'id': 'Impresiones_med',
#    'label': 'Impresiones_med',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_iqr': {'id': 'Impresiones_iqr',
#    'label': 'Impresiones_iqr',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_max': {'id': 'Impresiones_max',
#    'label': 'Impresiones_max',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Impresiones_min': {'id': 'Impresiones_min',
#    'label': 'Impresiones_min',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_q1': {'id': 'Clicks_q1',
#    'label': 'Clicks_q1',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_q3': {'id': 'Clicks_q3',
#    'label': 'Clicks_q3',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_med': {'id': 'Clicks_med',
#    'label': 'Clicks_med',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_iqr': {'id': 'Clicks_iqr',
#    'label': 'Clicks_iqr',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_max': {'id': 'Clicks_max',
#    'label': 'Clicks_max',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Clicks_min': {'id': 'Clicks_min',
#    'label': 'Clicks_min',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_q1': {'id': 'Cpc_q1',
#    'label': 'Cpc_q1',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_q3': {'id': 'Cpc_q3',
#    'label': 'Cpc_q3',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_med': {'id': 'Cpc_med',
#    'label': 'Cpc_med',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_iqr': {'id': 'Cpc_iqr',
#    'label': 'Cpc_iqr',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_max': {'id': 'Cpc_max',
#    'label': 'Cpc_max',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Cpc_min': {'id': 'Cpc_min',
#    'label': 'Cpc_min',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_q1': {'id': 'Qs_q1',
#    'label': 'Qs_q1',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_q3': {'id': 'Qs_q3',
#    'label': 'Qs_q3',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_med': {'id': 'Qs_med',
#    'label': 'Qs_med',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_iqr': {'id': 'Qs_iqr',
#    'label': 'Qs_iqr',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_max': {'id': 'Qs_max',
#    'label': 'Qs_max',
#    'status': 'empty',
#    'context': {},
#    'metadata': []},
#   'Qs_min': {'id': 'Qs_min',
#    'label': 'Qs_min',
#    'status': 'empty',
#    'context': {},
#    'metadata': []}},
#  'rows': {'r0': {'id': 'r0',
#    'cells': {'Fecha_id': {'id': 'r0$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r0$Cuenta_id', 'label': '1018571837', 'metadata': []},
#     'Campaña_id': {'id': 'r0$Campaña_id',
#      'label': '17309187968',
#      'metadata': []},
#     'Grupo_id': {'id': 'r0$Grupo_id',
#      'label': '138000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r0$Keyword_id',
#      'label': '299000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r0$City_id', 'label': '1023619', 'metadata': []},
#     'State_id': {'id': 'r0$State_id', 'label': '21168', 'metadata': []},
#     'Country_id': {'id': 'r0$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r0$Keyword',
#      'label': '5th third bank cd rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r0$Impresiones', 'label': '4', 'metadata': []},
#     'Clicks': {'id': 'r0$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r0$Cpc', 'label': '9000000', 'metadata': []},
#     'QualityScore': {'id': 'r0$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r0$City',
#      'label': 'Chardon',
#      'metadata': [{'id': 'georss:41.58339,-81.20288',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Chardon, OH, United States',
#         'uri': 'http://www.google.com/maps/place/41.58339,-81.20288'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r0$County', 'label': 'Ohio', 'metadata': []},
#     'Country': {'id': 'r0$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r0$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r0$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r0$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r0$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r0$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r0$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r0$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r0$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r0$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r0$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r0$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r0$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r0$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r0$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r0$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r0$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r0$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r0$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r0$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r0$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r0$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r0$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r0$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r0$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r0$apparent_temperature_max',
#      'label': '29,9',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r0$apparent_temperature_min',
#      'label': '20,3',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r0$precipitation_sum',
#      'label': '10,6',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r1': {'id': 'r1',
#    'cells': {'Fecha_id': {'id': 'r1$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r1$Cuenta_id', 'label': '1018571837', 'metadata': []},
#     'Campaña_id': {'id': 'r1$Campaña_id',
#      'label': '17309187968',
#      'metadata': []},
#     'Grupo_id': {'id': 'r1$Grupo_id',
#      'label': '138000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r1$Keyword_id',
#      'label': '299000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r1$City_id', 'label': '1023631', 'metadata': []},
#     'State_id': {'id': 'r1$State_id', 'label': '21168', 'metadata': []},
#     'Country_id': {'id': 'r1$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r1$Keyword',
#      'label': '5th third bank cd rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r1$Impresiones', 'label': '4', 'metadata': []},
#     'Clicks': {'id': 'r1$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r1$Cpc', 'label': '9000000', 'metadata': []},
#     'QualityScore': {'id': 'r1$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r1$City',
#      'label': 'Cleveland',
#      'metadata': [{'id': 'georss:41.50473,-81.69074',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Cleveland, OH, United States',
#         'uri': 'http://www.google.com/maps/place/41.50473,-81.69074'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r1$County', 'label': 'Ohio', 'metadata': []},
#     'Country': {'id': 'r1$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r1$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r1$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r1$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r1$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r1$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r1$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r1$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r1$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r1$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r1$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r1$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r1$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r1$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r1$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r1$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r1$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r1$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r1$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r1$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r1$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r1$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r1$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r1$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r1$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r1$apparent_temperature_max',
#      'label': '30,7',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r1$apparent_temperature_min',
#      'label': '22,4',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r1$precipitation_sum',
#      'label': '5,1',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r2': {'id': 'r2',
#    'cells': {'Fecha_id': {'id': 'r2$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r2$Cuenta_id', 'label': '1018571837', 'metadata': []},
#     'Campaña_id': {'id': 'r2$Campaña_id',
#      'label': '17309187968',
#      'metadata': []},
#     'Grupo_id': {'id': 'r2$Grupo_id',
#      'label': '138000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r2$Keyword_id',
#      'label': '299000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r2$City_id', 'label': '1016367', 'metadata': []},
#     'State_id': {'id': 'r2$State_id', 'label': '21147', 'metadata': []},
#     'Country_id': {'id': 'r2$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r2$Keyword',
#      'label': '5th third bank cd rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r2$Impresiones', 'label': '5', 'metadata': []},
#     'Clicks': {'id': 'r2$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r2$Cpc', 'label': '9000000', 'metadata': []},
#     'QualityScore': {'id': 'r2$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r2$City',
#      'label': 'Chicago',
#      'metadata': [{'id': 'georss:41.88425,-87.63245',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Chicago, IL, United States',
#         'uri': 'http://www.google.com/maps/place/41.88425,-87.63245'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r2$County', 'label': 'Illinois', 'metadata': []},
#     'Country': {'id': 'r2$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r2$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r2$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r2$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r2$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r2$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r2$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r2$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r2$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r2$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r2$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r2$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r2$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r2$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r2$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r2$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r2$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r2$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r2$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r2$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r2$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r2$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r2$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r2$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r2$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r2$apparent_temperature_max',
#      'label': '32,4',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r2$apparent_temperature_min',
#      'label': '22,8',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r2$precipitation_sum',
#      'label': '16,2',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r3': {'id': 'r3',
#    'cells': {'Fecha_id': {'id': 'r3$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r3$Cuenta_id', 'label': '1018571837', 'metadata': []},
#     'Campaña_id': {'id': 'r3$Campaña_id',
#      'label': '17309187968',
#      'metadata': []},
#     'Grupo_id': {'id': 'r3$Grupo_id',
#      'label': '138000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r3$Keyword_id',
#      'label': '299000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r3$City_id', 'label': '1027744', 'metadata': []},
#     'State_id': {'id': 'r3$State_id', 'label': '21180', 'metadata': []},
#     'Country_id': {'id': 'r3$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r3$Keyword',
#      'label': '5th third bank cd rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r3$Impresiones', 'label': '4', 'metadata': []},
#     'Clicks': {'id': 'r3$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r3$Cpc', 'label': '9000000', 'metadata': []},
#     'QualityScore': {'id': 'r3$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r3$City',
#      'label': 'Seattle',
#      'metadata': [{'id': 'georss:47.60357,-122.32945',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Seattle, WA, United States',
#         'uri': 'http://www.google.com/maps/place/47.60357,-122.32945'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r3$County', 'label': 'Washington', 'metadata': []},
#     'Country': {'id': 'r3$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r3$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r3$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r3$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r3$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r3$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r3$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r3$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r3$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r3$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r3$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r3$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r3$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r3$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r3$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r3$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r3$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r3$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r3$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r3$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r3$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r3$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r3$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r3$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r3$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r3$apparent_temperature_max',
#      'label': '25',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r3$apparent_temperature_min',
#      'label': '11,3',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r3$precipitation_sum',
#      'label': '0',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r4': {'id': 'r4',
#    'cells': {'Fecha_id': {'id': 'r4$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r4$Cuenta_id', 'label': '1119272776', 'metadata': []},
#     'Campaña_id': {'id': 'r4$Campaña_id',
#      'label': '20325090181',
#      'metadata': []},
#     'Grupo_id': {'id': 'r4$Grupo_id',
#      'label': '154000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r4$Keyword_id',
#      'label': '2240000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r4$City_id', 'label': '1016359', 'metadata': []},
#     'State_id': {'id': 'r4$State_id', 'label': '21147', 'metadata': []},
#     'Country_id': {'id': 'r4$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r4$Keyword',
#      'label': 'p n c bank c d rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r4$Impresiones', 'label': '3', 'metadata': []},
#     'Clicks': {'id': 'r4$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r4$Cpc', 'label': '6130000', 'metadata': []},
#     'QualityScore': {'id': 'r4$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r4$City',
#      'label': 'Champaign',
#      'metadata': [{'id': 'georss:40.1142,-88.2435',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Champaign, IL, United States',
#         'uri': 'http://www.google.com/maps/place/40.1142,-88.2435'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r4$County', 'label': 'Illinois', 'metadata': []},
#     'Country': {'id': 'r4$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r4$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r4$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r4$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r4$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r4$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r4$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r4$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r4$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r4$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r4$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r4$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r4$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r4$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r4$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r4$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r4$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r4$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r4$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r4$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r4$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r4$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r4$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r4$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r4$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r4$apparent_temperature_max',
#      'label': '34,9',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r4$apparent_temperature_min',
#      'label': '23,1',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r4$precipitation_sum',
#      'label': '12,2',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r5': {'id': 'r5',
#    'cells': {'Fecha_id': {'id': 'r5$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r5$Cuenta_id', 'label': '1119272776', 'metadata': []},
#     'Campaña_id': {'id': 'r5$Campaña_id',
#      'label': '20325090181',
#      'metadata': []},
#     'Grupo_id': {'id': 'r5$Grupo_id',
#      'label': '154000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r5$Keyword_id',
#      'label': '2240000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r5$City_id', 'label': '1023815', 'metadata': []},
#     'State_id': {'id': 'r5$State_id', 'label': '21168', 'metadata': []},
#     'Country_id': {'id': 'r5$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r5$Keyword',
#      'label': 'p n c bank c d rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r5$Impresiones', 'label': '3', 'metadata': []},
#     'Clicks': {'id': 'r5$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r5$Cpc', 'label': '6130000', 'metadata': []},
#     'QualityScore': {'id': 'r5$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r5$City',
#      'label': 'Marion',
#      'metadata': [{'id': 'georss:40.55881,-85.66067',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, IN, United States',
#         'uri': 'http://www.google.com/maps/place/40.55881,-85.66067'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:40.58382,-83.12852',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, OH, United States',
#         'uri': 'http://www.google.com/maps/place/40.58382,-83.12852'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:35.68431,-82.00838',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, NC, United States',
#         'uri': 'http://www.google.com/maps/place/35.68431,-82.00838'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:42.03331,-91.59961',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, IA, United States',
#         'uri': 'http://www.google.com/maps/place/42.03331,-91.59961'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:37.73082,-88.93004',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, IL, United States',
#         'uri': 'http://www.google.com/maps/place/37.73082,-88.93004'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:35.21846,-90.19955',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, AR, United States',
#         'uri': 'http://www.google.com/maps/place/35.21846,-90.19955'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:36.83398,-81.51734',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, VA, United States',
#         'uri': 'http://www.google.com/maps/place/36.83398,-81.51734'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:34.17807,-79.4004',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, SC, United States',
#         'uri': 'http://www.google.com/maps/place/34.17807,-79.4004'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:29.5716,-98.13881',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, TX, United States',
#         'uri': 'http://www.google.com/maps/place/29.5716,-98.13881'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:44.67129,-88.88927',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, WI, United States',
#         'uri': 'http://www.google.com/maps/place/44.67129,-88.88927'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:37.33224,-88.08144',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, KY, United States',
#         'uri': 'http://www.google.com/maps/place/37.33224,-88.08144'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:41.70309,-70.76263',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, MA, United States',
#         'uri': 'http://www.google.com/maps/place/41.70309,-70.76263'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.1429,-77.18927',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, NY, United States',
#         'uri': 'http://www.google.com/maps/place/43.1429,-77.18927'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:32.63467,-87.31913',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, AL, United States',
#         'uri': 'http://www.google.com/maps/place/32.63467,-87.31913'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:48.09847,-114.64972',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, MT, United States',
#         'uri': 'http://www.google.com/maps/place/48.09847,-114.64972'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:38.34816,-97.02147',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, KS, United States',
#         'uri': 'http://www.google.com/maps/place/38.34816,-97.02147'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:44.10296,-85.14743',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, MI, United States',
#         'uri': 'http://www.google.com/maps/place/44.10296,-85.14743'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:32.42001,-88.65128',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, MS, United States',
#         'uri': 'http://www.google.com/maps/place/32.42001,-88.65128'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.42625,-97.26073',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion, SD, United States',
#         'uri': 'http://www.google.com/maps/place/43.42625,-97.26073'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:45.27883,-85.27118',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Marion Twp, MI, United States',
#         'uri': 'http://www.google.com/maps/place/45.27883,-85.27118'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r5$County', 'label': 'Ohio', 'metadata': []},
#     'Country': {'id': 'r5$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r5$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r5$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r5$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r5$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r5$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r5$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r5$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r5$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r5$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r5$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r5$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r5$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r5$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r5$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r5$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r5$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r5$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r5$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r5$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r5$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r5$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r5$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r5$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r5$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r5$apparent_temperature_max',
#      'label': '32,2',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r5$apparent_temperature_min',
#      'label': '22,6',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r5$precipitation_sum',
#      'label': '4,3',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r6': {'id': 'r6',
#    'cells': {'Fecha_id': {'id': 'r6$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r6$Cuenta_id', 'label': '1119272776', 'metadata': []},
#     'Campaña_id': {'id': 'r6$Campaña_id',
#      'label': '20325090181',
#      'metadata': []},
#     'Grupo_id': {'id': 'r6$Grupo_id',
#      'label': '154000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r6$Keyword_id',
#      'label': '2240000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r6$City_id', 'label': '1025531', 'metadata': []},
#     'State_id': {'id': 'r6$State_id', 'label': '21173', 'metadata': []},
#     'Country_id': {'id': 'r6$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r6$Keyword',
#      'label': 'p n c bank c d rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r6$Impresiones', 'label': '3', 'metadata': []},
#     'Clicks': {'id': 'r6$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r6$Cpc', 'label': '6130000', 'metadata': []},
#     'QualityScore': {'id': 'r6$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r6$City',
#      'label': 'Conway',
#      'metadata': [{'id': 'georss:35.09098,-92.43969',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, AR, United States',
#         'uri': 'http://www.google.com/maps/place/35.09098,-92.43969'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:33.83473,-79.05036',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, SC, United States',
#         'uri': 'http://www.google.com/maps/place/33.83473,-79.05036'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.97981,-71.10824',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, NH, United States',
#         'uri': 'http://www.google.com/maps/place/43.97981,-71.10824'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:42.5096,-72.69973',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, MA, United States',
#         'uri': 'http://www.google.com/maps/place/42.5096,-72.69973'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:37.50211,-92.82165',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, MO, United States',
#         'uri': 'http://www.google.com/maps/place/37.50211,-92.82165'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:48.23394,-97.6753',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, ND, United States',
#         'uri': 'http://www.google.com/maps/place/48.23394,-97.6753'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:40.74927,-94.6189',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, IA, United States',
#         'uri': 'http://www.google.com/maps/place/40.74927,-94.6189'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:40.66176,-80.23792',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, PA, United States',
#         'uri': 'http://www.google.com/maps/place/40.66176,-80.23792'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:36.43709,-77.22957',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, NC, United States',
#         'uri': 'http://www.google.com/maps/place/36.43709,-77.22957'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:48.34129,-122.34526',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, WA, United States',
#         'uri': 'http://www.google.com/maps/place/48.34129,-122.34526'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:45.42115,-84.86313',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, MI, United States',
#         'uri': 'http://www.google.com/maps/place/45.42115,-84.86313'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:-20.47189,148.73401',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Conway, QLD 4800, Australia',
#         'uri': 'http://www.google.com/maps/place/-20.47189,148.73401'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r6$County', 'label': 'South Carolina', 'metadata': []},
#     'Country': {'id': 'r6$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r6$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r6$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r6$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r6$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r6$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r6$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r6$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r6$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r6$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r6$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r6$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r6$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r6$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r6$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r6$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r6$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r6$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r6$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r6$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r6$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r6$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r6$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r6$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r6$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r6$apparent_temperature_max',
#      'label': '40,1',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r6$apparent_temperature_min',
#      'label': '29,8',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r6$precipitation_sum',
#      'label': '4,4',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r7': {'id': 'r7',
#    'cells': {'Fecha_id': {'id': 'r7$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r7$Cuenta_id', 'label': '1119272776', 'metadata': []},
#     'Campaña_id': {'id': 'r7$Campaña_id',
#      'label': '20325090181',
#      'metadata': []},
#     'Grupo_id': {'id': 'r7$Grupo_id',
#      'label': '154000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r7$Keyword_id',
#      'label': '2240000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r7$City_id', 'label': '1026730', 'metadata': []},
#     'State_id': {'id': 'r7$State_id', 'label': '21176', 'metadata': []},
#     'Country_id': {'id': 'r7$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r7$Keyword',
#      'label': 'p n c bank c d rates',
#      'metadata': []},
#     'Impresiones': {'id': 'r7$Impresiones', 'label': '2', 'metadata': []},
#     'Clicks': {'id': 'r7$Clicks', 'label': '5', 'metadata': []},
#     'Cpc': {'id': 'r7$Cpc', 'label': '6130000', 'metadata': []},
#     'QualityScore': {'id': 'r7$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r7$City',
#      'label': 'Richmond',
#      'metadata': [{'id': 'georss:37.54068,-77.43367',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Richmond, VA, United States',
#         'uri': 'http://www.google.com/maps/place/37.54068,-77.43367'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
# ...
#        'name': {'value': 'Havelock, Marlborough, New Zealand',
#         'uri': 'http://www.google.com/maps/place/-41.281,173.76715'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:42.83483,-94.70171',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Havelock, IA, United States',
#         'uri': 'http://www.google.com/maps/place/42.83483,-94.70171'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:-36.96529,143.77288',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Havelock, VIC 3465, Australia',
#         'uri': 'http://www.google.com/maps/place/-36.96529,143.77288'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r15$County', 'label': 'North Carolina', 'metadata': []},
#     'Country': {'id': 'r15$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r15$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r15$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r15$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r15$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r15$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r15$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r15$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r15$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r15$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r15$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r15$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r15$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r15$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r15$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r15$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r15$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r15$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r15$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r15$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r15$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r15$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r15$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r15$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r15$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r15$apparent_temperature_max',
#      'label': '37',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r15$apparent_temperature_min',
#      'label': '24,7',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r15$precipitation_sum',
#      'label': '0,1',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r16': {'id': 'r16',
#    'cells': {'Fecha_id': {'id': 'r16$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r16$Cuenta_id',
#      'label': '1150766542',
#      'metadata': []},
#     'Campaña_id': {'id': 'r16$Campaña_id',
#      'label': '18850329589',
#      'metadata': []},
#     'Grupo_id': {'id': 'r16$Grupo_id',
#      'label': '148000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r16$Keyword_id',
#      'label': '352000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r16$City_id', 'label': '9052608', 'metadata': []},
#     'State_id': {'id': 'r16$State_id', 'label': '21136', 'metadata': []},
#     'Country_id': {'id': 'r16$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r16$Keyword',
#      'label': 'armed forces recruiting',
#      'metadata': []},
#     'Impresiones': {'id': 'r16$Impresiones', 'label': '4', 'metadata': []},
#     'Clicks': {'id': 'r16$Clicks', 'label': '4', 'metadata': []},
#     'Cpc': {'id': 'r16$Cpc', 'label': '6900000', 'metadata': []},
#     'QualityScore': {'id': 'r16$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r16$City',
#      'label': 'Oro Valley',
#      'metadata': [{'id': 'georss:32.4078,-110.99569',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Oro Valley, AZ, United States',
#         'uri': 'http://www.google.com/maps/place/32.4078,-110.99569'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r16$County', 'label': 'Arizona', 'metadata': []},
#     'Country': {'id': 'r16$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r16$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r16$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r16$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r16$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r16$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r16$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r16$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r16$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r16$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r16$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r16$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r16$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r16$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r16$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r16$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r16$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r16$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r16$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r16$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r16$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r16$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r16$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r16$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r16$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r16$apparent_temperature_max',
#      'label': '36,1',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r16$apparent_temperature_min',
#      'label': '22,2',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r16$precipitation_sum',
#      'label': '0',
#      'metadata': [],
#      'annotationMeta': {}}}},
#   'r17': {'id': 'r17',
#    'cells': {'Fecha_id': {'id': 'r17$Fecha_id',
#      'label': '2023-07-01',
#      'metadata': []},
#     'Cuenta_id': {'id': 'r17$Cuenta_id',
#      'label': '1333143884',
#      'metadata': []},
#     'Campaña_id': {'id': 'r17$Campaña_id',
#      'label': '20071681157',
#      'metadata': []},
#     'Grupo_id': {'id': 'r17$Grupo_id',
#      'label': '148000000000.0',
#      'metadata': []},
#     'Keyword_id': {'id': 'r17$Keyword_id',
#      'label': '352000000000.0',
#      'metadata': []},
#     'City_id': {'id': 'r17$City_id', 'label': '1014964', 'metadata': []},
#     'State_id': {'id': 'r17$State_id', 'label': '21142', 'metadata': []},
#     'Country_id': {'id': 'r17$Country_id', 'label': '2840', 'metadata': []},
#     'Keyword': {'id': 'r17$Keyword',
#      'label': 'armed forces recruiting',
#      'metadata': []},
#     'Impresiones': {'id': 'r17$Impresiones', 'label': '39', 'metadata': []},
#     'Clicks': {'id': 'r17$Clicks', 'label': '0', 'metadata': []},
#     'Cpc': {'id': 'r17$Cpc', 'label': '20000', 'metadata': []},
#     'QualityScore': {'id': 'r17$QualityScore', 'label': '', 'metadata': []},
#     'City': {'id': 'r17$City',
#      'label': 'Brandon',
#      'metadata': [{'id': 'georss:49.84937,-99.96192',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, MB, Canada',
#         'uri': 'http://www.google.com/maps/place/49.84937,-99.96192'},
#        'score': 1,
#        'match': True,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:27.94015,-82.32543',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, FL, United States',
#         'uri': 'http://www.google.com/maps/place/27.94015,-82.32543'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:52.44274,0.62621',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, England, United Kingdom',
#         'uri': 'http://www.google.com/maps/place/52.44274,0.62621'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:32.27313,-89.98891',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, MS, United States',
#         'uri': 'http://www.google.com/maps/place/32.27313,-89.98891'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.80005,-73.09263',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, VT, United States',
#         'uri': 'http://www.google.com/maps/place/43.80005,-73.09263'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.59441,-96.57235',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, SD, United States',
#         'uri': 'http://www.google.com/maps/place/43.59441,-96.57235'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:-19.55431,147.35412',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, QLD 4808, Australia',
#         'uri': 'http://www.google.com/maps/place/-19.55431,147.35412'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:45.96393,-95.59951',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, MN, United States',
#         'uri': 'http://www.google.com/maps/place/45.96393,-95.59951'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:44.76241,-74.42118',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, NY, United States',
#         'uri': 'http://www.google.com/maps/place/44.76241,-74.42118'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:42.3145,-92.00643',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, IA, United States',
#         'uri': 'http://www.google.com/maps/place/42.3145,-92.00643'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:43.73449,-88.77773',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brandon, WI, United States',
#         'uri': 'http://www.google.com/maps/place/43.73449,-88.77773'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]},
#       {'id': 'georss:65.6967,22.33465',
#        'feature': [{'id': 'all_labels', 'value': 100}],
#        'name': {'value': 'Brändön, Norrbotten County, Sweden',
#         'uri': 'http://www.google.com/maps/place/65.6967,22.33465'},
#        'score': 1,
#        'match': False,
#        'type': [{'id': 'wd:Q29934236', 'name': 'GlobeCoordinate'},
#         {'id': 'georss:point', 'name': 'point'}]}],
#      'annotationMeta': {'annotated': True,
#       'match': {'value': True},
#       'lowestScore': 1,
#       'highestScore': 1}},
#     'County': {'id': 'r17$County', 'label': 'Florida', 'metadata': []},
#     'Country': {'id': 'r17$Country', 'label': 'United States', 'metadata': []},
#     'Impresiones_q1': {'id': 'r17$Impresiones_q1',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_q3': {'id': 'r17$Impresiones_q3',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_med': {'id': 'r17$Impresiones_med',
#      'label': '1',
#      'metadata': []},
#     'Impresiones_iqr': {'id': 'r17$Impresiones_iqr',
#      'label': '0',
#      'metadata': []},
#     'Impresiones_max': {'id': 'r17$Impresiones_max',
#      'label': '2794',
#      'metadata': []},
#     'Impresiones_min': {'id': 'r17$Impresiones_min',
#      'label': '0',
#      'metadata': []},
#     'Clicks_q1': {'id': 'r17$Clicks_q1', 'label': '0', 'metadata': []},
#     'Clicks_q3': {'id': 'r17$Clicks_q3', 'label': '0', 'metadata': []},
#     'Clicks_med': {'id': 'r17$Clicks_med', 'label': '0', 'metadata': []},
#     'Clicks_iqr': {'id': 'r17$Clicks_iqr', 'label': '0', 'metadata': []},
#     'Clicks_max': {'id': 'r17$Clicks_max', 'label': '148', 'metadata': []},
#     'Clicks_min': {'id': 'r17$Clicks_min', 'label': '0', 'metadata': []},
#     'Cpc_q1': {'id': 'r17$Cpc_q1', 'label': '160000', 'metadata': []},
#     'Cpc_q3': {'id': 'r17$Cpc_q3', 'label': '620000', 'metadata': []},
#     'Cpc_med': {'id': 'r17$Cpc_med', 'label': '300000', 'metadata': []},
#     'Cpc_iqr': {'id': 'r17$Cpc_iqr', 'label': '460000', 'metadata': []},
#     'Cpc_max': {'id': 'r17$Cpc_max', 'label': '999000000', 'metadata': []},
#     'Cpc_min': {'id': 'r17$Cpc_min', 'label': '10000', 'metadata': []},
#     'Qs_q1': {'id': 'r17$Qs_q1', 'label': '0', 'metadata': []},
#     'Qs_q3': {'id': 'r17$Qs_q3', 'label': '0', 'metadata': []},
#     'Qs_med': {'id': 'r17$Qs_med', 'label': '0', 'metadata': []},
#     'Qs_iqr': {'id': 'r17$Qs_iqr', 'label': '0', 'metadata': []},
#     'Qs_max': {'id': 'r17$Qs_max', 'label': '10', 'metadata': []},
#     'Qs_min': {'id': 'r17$Qs_min', 'label': '0', 'metadata': []},
#     'apparent_temperature_max': {'id': 'r17$apparent_temperature_max',
#      'label': '30,2',
#      'metadata': [],
#      'annotationMeta': {}},
#     'apparent_temperature_min': {'id': 'r17$apparent_temperature_min',
#      'label': '16',
#      'metadata': [],
#      'annotationMeta': {}},
#     'precipitation_sum': {'id': 'r17$precipitation_sum',
#      'label': '0',
#      'metadata': [],
#      'annotationMeta': {}}}}}}

# %%
import json
import pandas as pd

# Load the JSON data from file
data = New_data

# Assuming 'columns' and 'rows' keys are correctly located
columns = data['columns']
rows = data['rows']

# Creating a list of dictionaries for each row
data_list = []
for row_id, row_info in rows.items():
    row_data = {}
    # Include all cell keys from the row, not just those listed in the columns dictionary
    for cell_key, cell_value in row_info['cells'].items():
        row_data[cell_key] = cell_value['label']
    data_list.append(row_data)

# Convert list to DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
print(df)
# Out:
#       Fecha_id   Cuenta_id   Campaña_id        Grupo_id       Keyword_id  City_id State_id Country_id                  Keyword Impresiones Clicks      Cpc QualityScore                 City          County        Country Impresiones_q1 Impresiones_q3 Impresiones_med Impresiones_iqr Impresiones_max Impresiones_min Clicks_q1 Clicks_q3 Clicks_med Clicks_iqr Clicks_max Clicks_min  Cpc_q1  Cpc_q3 Cpc_med Cpc_iqr    Cpc_max Cpc_min Qs_q1 Qs_q3 Qs_med Qs_iqr Qs_max Qs_min apparent_temperature_max apparent_temperature_min precipitation_sum
# 0   2023-07-01  1018571837  17309187968  138000000000.0   299000000000.0  1023619    21168       2840  5th third bank cd rates           4      5  9000000                           Chardon            Ohio  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     29,9                     20,3              10,6
# 1   2023-07-01  1018571837  17309187968  138000000000.0   299000000000.0  1023631    21168       2840  5th third bank cd rates           4      5  9000000                         Cleveland            Ohio  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     30,7                     22,4               5,1
# 2   2023-07-01  1018571837  17309187968  138000000000.0   299000000000.0  1016367    21147       2840  5th third bank cd rates           5      5  9000000                           Chicago        Illinois  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     32,4                     22,8              16,2
# 3   2023-07-01  1018571837  17309187968  138000000000.0   299000000000.0  1027744    21180       2840  5th third bank cd rates           4      5  9000000                           Seattle      Washington  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                       25                     11,3                 0
# 4   2023-07-01  1119272776  20325090181  154000000000.0  2240000000000.0  1016359    21147       2840     p n c bank c d rates           3      5  6130000                         Champaign        Illinois  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     34,9                     23,1              12,2
# 5   2023-07-01  1119272776  20325090181  154000000000.0  2240000000000.0  1023815    21168       2840     p n c bank c d rates           3      5  6130000                            Marion            Ohio  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     32,2                     22,6               4,3
# 6   2023-07-01  1119272776  20325090181  154000000000.0  2240000000000.0  1025531    21173       2840     p n c bank c d rates           3      5  6130000                            Conway  South Carolina  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     40,1                     29,8               4,4
# 7   2023-07-01  1119272776  20325090181  154000000000.0  2240000000000.0  1026730    21176       2840     p n c bank c d rates           2      5  6130000                          Richmond           Texas  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     36,5                     21,9               1,7
# 8   2023-07-01  1119272776  20325090181  154000000000.0  2240000000000.0  9052594    21164       2840     p n c bank c d rates           2      5  6130000               Old Bridge Township      New Jersey  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     27,5                     19,4                 0
# 9   2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1026481    21176       2840  armed forces recruiting           5      4  6900000                           Houston           Texas  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     42,2                     31,3                 0
# 10  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1014306    21137       2840  armed forces recruiting           5      4  6900000                          Stockton      California  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     41,6                     19,8                 0
# 11  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1015529    21143       2840  armed forces recruiting           5      4  6900000                         Thomaston         Georgia  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     41,4                       26               9,1
# 12  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1014444    21138       2840  armed forces recruiting           4      4  6900000                           Bennett        Colorado  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     23,9                     11,2                 0
# 13  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1019232    21155       2840  armed forces recruiting           4      4  6900000                      Coopersville        Michigan  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     31,9                     21,1               2,4
# 14  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1022968    21167       2840  armed forces recruiting           4      4  6900000                           Hamburg        New York  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     17,7                     14,2               5,9
# 15  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  1021141    21160       2840  armed forces recruiting           4      4  6900000                          Havelock  North Carolina  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                       37                     24,7               0,1
# 16  2023-07-01  1150766542  18850329589  148000000000.0   352000000000.0  9052608    21136       2840  armed forces recruiting           4      4  6900000                        Oro Valley         Arizona  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     36,1                     22,2                 0
# 17  2023-07-01  1333143884  20071681157  148000000000.0   352000000000.0  1014964    21142       2840  armed forces recruiting          39      0    20000                           Brandon         Florida  United States              1              1               1               0            2794               0         0         0          0          0        148          0  160000  620000  300000  460000  999000000   10000     0     0      0      0     10      0                     30,2                       16                 0

# %%
def create_update_payload(table_json):
    """
    Creates the payload required to perform the table update operation

    :param table_json: JSON representation of the table
    :return: request payload
    """
    payload = {
        "tableInstance": {
            "id": table_json["table"]["id"],
            "idDataset": table_json["table"]["idDataset"],
            "name": table_json["table"]["name"],
            "nCols": table_json["table"]["nCols"],
            "nRows": table_json["table"]["nRows"],
            "nCells": table_json["table"]["nCells"],
            "nCellsReconciliated": table_json["table"]["nCellsReconciliated"],
            "lastModifiedDate": table_json["table"]["lastModifiedDate"],
            "minMetaScore": table_json["table"]["minMetaScore"],
            "maxMetaScore": table_json["table"]["maxMetaScore"]
        },
        "columns": {
            "byId": {},
            "allIds": []
        },
        "rows": {
            "byId": {},
            "allIds": []
        }
    }

    # Process columns
    for column_id, column_data in table_json["columns"].items():
        payload["columns"]["byId"][column_id] = {
            "id": column_data["id"],
            "label": column_data["label"],
            "status": column_data["status"],
            "context": column_data["context"],
            "metadata": column_data["metadata"],
            "annotationMeta": column_data.get("annotationMeta", {})
        }
        payload["columns"]["allIds"].append(column_id)

    # Process rows
    for row_id, row_data in table_json["rows"].items():
        payload["rows"]["byId"][row_id] = {
            "id": row_data["id"],
            "cells": {}
        }
        for cell_id, cell_data in row_data["cells"].items():
            payload["rows"]["byId"][row_id]["cells"][cell_id] = {
                "id": cell_data["id"],
                "label": cell_data["label"],
                "metadata": cell_data["metadata"],
                "annotationMeta": cell_data.get("annotationMeta", {})
            }
        payload["rows"]["allIds"].append(row_id)

    return payload

# %%
# API configuration
API_URL = "http://localhost:3003/api/"
DATASETS_ENDPOINT = "dataset/"
dataset_id = "13"
table_id = "44"

token = token_manager.get_token()
headers = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application/json'
}

url = f"{API_URL}{DATASETS_ENDPOINT}{dataset_id}/table/{table_id}"

# Create the update payload
update_payload = create_update_payload(New_data)

try:
    # Send the PUT request to update the table
    response = requests.put(url, headers=headers, json=update_payload)
    
    if response.status_code == 200:
        print("Table updated successfully!")
        response_data = response.json()
        print("Response data:", response_data)
    elif response.status_code == 401:
        print("Unauthorized: Invalid or missing token.")
    elif response.status_code == 404:
        print(f"Dataset or table with ID {dataset_id}/{table_id} not found.")
    else:
        print(f"Failed to update table: {response.status_code}, {response.text}")
except requests.exceptions.RequestException as e:
    print(f"Error occurred while updating table: {e}")
# Out:
# Table updated successfully!
# Response data: {'id': '44', 'idDataset': '13', 'name': 'JOT_Date_Transformed2', 'nCols': 40, 'nRows': 18, 'nCells': 720, 'nCellsReconciliated': 18, 'lastModifiedDate': '2024-05-06T10:54:15.115Z', 'minMetaScore': 0.91, 'maxMetaScore': 1}

# %%
# Example usage
dataset_id = "13"
table_name = "JOT_Date_Transformed2"  # Replace with the desired table name

table_json = get_table_by_name(dataset_id, table_name, token_manager)

if table_json is not None:
    # Process the table data as needed
    print("Table JSON:")
    print(json.dumps(table_json, indent=2))
# Out:
# Table JSON:
# {
#   "table": {
#     "id": "44",
#     "idDataset": "13",
#     "name": "JOT_Date_Transformed2",
#     "nCols": 40,
#     "nRows": 18,
#     "nCells": 720,
#     "nCellsReconciliated": 18,
#     "lastModifiedDate": "2024-05-06T10:54:15.115Z",
#     "minMetaScore": 0.91,
#     "maxMetaScore": 1
#   },
#   "columns": {
#     "Fecha_id": {
#       "id": "Fecha_id",
#       "label": "Fecha_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cuenta_id": {
#       "id": "Cuenta_id",
#       "label": "Cuenta_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Campa\u00f1a_id": {
#       "id": "Campa\u00f1a_id",
#       "label": "Campa\u00f1a_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Grupo_id": {
#       "id": "Grupo_id",
#       "label": "Grupo_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Keyword_id": {
#       "id": "Keyword_id",
#       "label": "Keyword_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "City_id": {
#       "id": "City_id",
#       "label": "City_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "State_id": {
#       "id": "State_id",
#       "label": "State_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Country_id": {
#       "id": "Country_id",
#       "label": "Country_id",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Keyword": {
#       "id": "Keyword",
#       "label": "Keyword",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones": {
#       "id": "Impresiones",
#       "label": "Impresiones",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks": {
#       "id": "Clicks",
#       "label": "Clicks",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc": {
#       "id": "Cpc",
#       "label": "Cpc",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "QualityScore": {
#       "id": "QualityScore",
#       "label": "QualityScore",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "City": {
#       "id": "City",
#       "label": "City",
#       "status": "pending",
#       "context": {
#         "georss": {
#           "uri": "http://www.google.com/maps/place/",
#           "total": 18,
#           "reconciliated": 18
#         }
#       },
#       "metadata": [
#         {
#           "id": "",
#           "match": true,
#           "score": 0,
#           "name": {
#             "value": "",
#             "uri": ""
#           },
#           "entity": [
#             {
#               "id": "wd:Q29934236",
#               "name": {
#                 "value": "GlobeCoordinate",
#                 "uri": "http://www.google.com/maps/place/Q29934236"
#               },
#               "score": 0,
#               "match": true,
#               "type": []
#             },
#             {
#               "id": "georss:point",
#               "name": {
#                 "value": "point",
#                 "uri": "http://www.google.com/maps/place/point"
#               },
#               "score": 0,
#               "match": true,
#               "type": []
#             }
#           ],
#           "property": [],
#           "type": [
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             },
#             {
#               "id": "wd:Q29934236",
#               "name": "GlobeCoordinate"
#             }
#           ]
#         }
#       ],
#       "annotationMeta": {
#         "annotated": true,
#         "match": {
#           "value": true
#         },
#         "lowestScore": 0.91,
#         "highestScore": 1
#       }
#     },
#     "County": {
#       "id": "County",
#       "label": "County",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Country": {
#       "id": "Country",
#       "label": "Country",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_q1": {
#       "id": "Impresiones_q1",
#       "label": "Impresiones_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_q3": {
#       "id": "Impresiones_q3",
#       "label": "Impresiones_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_med": {
#       "id": "Impresiones_med",
#       "label": "Impresiones_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_iqr": {
#       "id": "Impresiones_iqr",
#       "label": "Impresiones_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_max": {
#       "id": "Impresiones_max",
#       "label": "Impresiones_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Impresiones_min": {
#       "id": "Impresiones_min",
#       "label": "Impresiones_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_q1": {
#       "id": "Clicks_q1",
#       "label": "Clicks_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_q3": {
#       "id": "Clicks_q3",
#       "label": "Clicks_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_med": {
#       "id": "Clicks_med",
#       "label": "Clicks_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_iqr": {
#       "id": "Clicks_iqr",
#       "label": "Clicks_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_max": {
#       "id": "Clicks_max",
#       "label": "Clicks_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Clicks_min": {
#       "id": "Clicks_min",
#       "label": "Clicks_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_q1": {
#       "id": "Cpc_q1",
#       "label": "Cpc_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_q3": {
#       "id": "Cpc_q3",
#       "label": "Cpc_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_med": {
#       "id": "Cpc_med",
#       "label": "Cpc_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_iqr": {
#       "id": "Cpc_iqr",
#       "label": "Cpc_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_max": {
#       "id": "Cpc_max",
#       "label": "Cpc_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Cpc_min": {
#       "id": "Cpc_min",
#       "label": "Cpc_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_q1": {
#       "id": "Qs_q1",
#       "label": "Qs_q1",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_q3": {
#       "id": "Qs_q3",
#       "label": "Qs_q3",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_med": {
#       "id": "Qs_med",
#       "label": "Qs_med",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_iqr": {
#       "id": "Qs_iqr",
#       "label": "Qs_iqr",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_max": {
#       "id": "Qs_max",
#       "label": "Qs_max",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     },
#     "Qs_min": {
#       "id": "Qs_min",
#       "label": "Qs_min",
#       "status": "empty",
#       "context": {},
#       "metadata": []
#     }
#   },
#   "rows": {
#     "r0": {
#       "id": "r0",
#       "cells": {
#         "Fecha_id": {
#           "id": "r0$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r0$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r0$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r0$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r0$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r0$City_id",
#           "label": "1023619",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r0$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r0$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r0$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r0$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r0$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r0$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r0$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r0$City",
#           "label": "Chardon",
#           "metadata": [
#             {
#               "id": "georss:41.58339,-81.20288",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Chardon, OH, United States",
#                 "uri": "http://www.google.com/maps/place/41.58339,-81.20288"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r0$County",
#           "label": "Ohio",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r0$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r0$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r0$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r0$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r0$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r0$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r0$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r0$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r0$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r0$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r0$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r0$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r0$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r0$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r0$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r0$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r0$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r0$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r0$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r0$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r0$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r0$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r0$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r0$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r0$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r0$apparent_temperature_max",
#           "label": "29,9",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r0$apparent_temperature_min",
#           "label": "20,3",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r0$precipitation_sum",
#           "label": "10,6",
#           "metadata": []
#         }
#       }
#     },
#     "r1": {
#       "id": "r1",
#       "cells": {
#         "Fecha_id": {
#           "id": "r1$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r1$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r1$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r1$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r1$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r1$City_id",
#           "label": "1023631",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r1$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r1$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r1$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r1$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r1$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r1$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r1$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r1$City",
#           "label": "Cleveland",
#           "metadata": [
#             {
#               "id": "georss:41.50473,-81.69074",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Cleveland, OH, United States",
#                 "uri": "http://www.google.com/maps/place/41.50473,-81.69074"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r1$County",
#           "label": "Ohio",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r1$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r1$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r1$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r1$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r1$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r1$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r1$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r1$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r1$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r1$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r1$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r1$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r1$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r1$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r1$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r1$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r1$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r1$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r1$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r1$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r1$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r1$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r1$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r1$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r1$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r1$apparent_temperature_max",
#           "label": "30,7",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r1$apparent_temperature_min",
#           "label": "22,4",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r1$precipitation_sum",
#           "label": "5,1",
#           "metadata": []
#         }
#       }
#     },
#     "r2": {
#       "id": "r2",
#       "cells": {
#         "Fecha_id": {
#           "id": "r2$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r2$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r2$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r2$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r2$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r2$City_id",
#           "label": "1016367",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r2$State_id",
#           "label": "21147",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r2$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r2$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r2$Impresiones",
#           "label": "5",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r2$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r2$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r2$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r2$City",
#           "label": "Chicago",
#           "metadata": [
#             {
#               "id": "georss:41.88425,-87.63245",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Chicago, IL, United States",
#                 "uri": "http://www.google.com/maps/place/41.88425,-87.63245"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r2$County",
#           "label": "Illinois",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r2$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r2$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r2$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r2$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r2$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r2$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r2$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r2$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r2$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r2$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r2$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r2$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r2$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r2$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r2$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r2$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r2$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r2$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r2$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r2$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r2$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r2$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r2$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r2$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r2$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r2$apparent_temperature_max",
#           "label": "32,4",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r2$apparent_temperature_min",
#           "label": "22,8",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r2$precipitation_sum",
#           "label": "16,2",
#           "metadata": []
#         }
#       }
#     },
#     "r3": {
#       "id": "r3",
#       "cells": {
#         "Fecha_id": {
#           "id": "r3$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r3$Cuenta_id",
#           "label": "1018571837",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r3$Campa\u00f1a_id",
#           "label": "17309187968",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r3$Grupo_id",
#           "label": "138000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r3$Keyword_id",
#           "label": "299000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r3$City_id",
#           "label": "1027744",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r3$State_id",
#           "label": "21180",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r3$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r3$Keyword",
#           "label": "5th third bank cd rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r3$Impresiones",
#           "label": "4",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r3$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r3$Cpc",
#           "label": "9000000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r3$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r3$City",
#           "label": "Seattle",
#           "metadata": [
#             {
#               "id": "georss:47.60357,-122.32945",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Seattle, WA, United States",
#                 "uri": "http://www.google.com/maps/place/47.60357,-122.32945"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r3$County",
#           "label": "Washington",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r3$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r3$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r3$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r3$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r3$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r3$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r3$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r3$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r3$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r3$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r3$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r3$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r3$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r3$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r3$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r3$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r3$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r3$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r3$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r3$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r3$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r3$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r3$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r3$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r3$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r3$apparent_temperature_max",
#           "label": "25",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r3$apparent_temperature_min",
#           "label": "11,3",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r3$precipitation_sum",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r4": {
#       "id": "r4",
#       "cells": {
#         "Fecha_id": {
#           "id": "r4$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r4$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r4$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r4$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r4$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r4$City_id",
#           "label": "1016359",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r4$State_id",
#           "label": "21147",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r4$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r4$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r4$Impresiones",
#           "label": "3",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r4$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r4$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r4$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r4$City",
#           "label": "Champaign",
#           "metadata": [
#             {
#               "id": "georss:40.1142,-88.2435",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Champaign, IL, United States",
#                 "uri": "http://www.google.com/maps/place/40.1142,-88.2435"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r4$County",
#           "label": "Illinois",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r4$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r4$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r4$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r4$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r4$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r4$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r4$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r4$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r4$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r4$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r4$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r4$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r4$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r4$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r4$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r4$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r4$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r4$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r4$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r4$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r4$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r4$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r4$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r4$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r4$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r4$apparent_temperature_max",
#           "label": "34,9",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r4$apparent_temperature_min",
#           "label": "23,1",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r4$precipitation_sum",
#           "label": "12,2",
#           "metadata": []
#         }
#       }
#     },
#     "r5": {
#       "id": "r5",
#       "cells": {
#         "Fecha_id": {
#           "id": "r5$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r5$Cuenta_id",
#           "label": "1119272776",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r5$Campa\u00f1a_id",
#           "label": "20325090181",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r5$Grupo_id",
#           "label": "154000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r5$Keyword_id",
#           "label": "2240000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r5$City_id",
#           "label": "1023815",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r5$State_id",
#           "label": "21168",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r5$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r5$Keyword",
#           "label": "p n c bank c d rates",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r5$Impresiones",
#           "label": "3",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r5$Clicks",
#           "label": "5",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r5$Cpc",
#           "label": "6130000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r5$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r5$City",
#           "label": "Marion",
#           "metadata": [
#             {
#               "id": "georss:40.55881,-85.66067",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, IN, United States",
#                 "uri": "http://www.google.com/maps/place/40.55881,-85.66067"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:40.58382,-83.12852",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, OH, United States",
#                 "uri": "http://www.google.com/maps/place/40.58382,-83.12852"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:35.68431,-82.00838",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, NC, United States",
#                 "uri": "http://www.google.com/maps/place/35.68431,-82.00838"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:42.03331,-91.59961",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, IA, United States",
#                 "uri": "http://www.google.com/maps/place/42.03331,-91.59961"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:37.73082,-88.93004",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, IL, United States",
#                 "uri": "http://www.google.com/maps/place/37.73082,-88.93004"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:35.21846,-90.19955",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, AR, United States",
#                 "uri": "http://www.google.com/maps/place/35.21846,-90.19955"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:36.83398,-81.51734",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, VA, United States",
#                 "uri": "http://www.google.com/maps/place/36.83398,-81.51734"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:34.17807,-79.4004",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, SC, United States",
#                 "uri": "http://www.google.com/maps/place/34.17807,-79.4004"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:29.5716,-98.13881",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, TX, United States",
#                 "uri": "http://www.google.com/maps/place/29.5716,-98.13881"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:44.67129,-88.88927",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Marion, WI, United States",
#                 "uri": "http://www.google.com/maps/place/44.67129,-88.88927"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
# ...
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r16$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r16$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r16$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r16$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r16$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r16$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r16$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r16$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r16$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r16$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r16$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r16$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r16$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r16$apparent_temperature_max",
#           "label": "36,1",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r16$apparent_temperature_min",
#           "label": "22,2",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r16$precipitation_sum",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     },
#     "r17": {
#       "id": "r17",
#       "cells": {
#         "Fecha_id": {
#           "id": "r17$Fecha_id",
#           "label": "2023-07-01",
#           "metadata": []
#         },
#         "Cuenta_id": {
#           "id": "r17$Cuenta_id",
#           "label": "1333143884",
#           "metadata": []
#         },
#         "Campa\u00f1a_id": {
#           "id": "r17$Campa\u00f1a_id",
#           "label": "20071681157",
#           "metadata": []
#         },
#         "Grupo_id": {
#           "id": "r17$Grupo_id",
#           "label": "148000000000.0",
#           "metadata": []
#         },
#         "Keyword_id": {
#           "id": "r17$Keyword_id",
#           "label": "352000000000.0",
#           "metadata": []
#         },
#         "City_id": {
#           "id": "r17$City_id",
#           "label": "1014964",
#           "metadata": []
#         },
#         "State_id": {
#           "id": "r17$State_id",
#           "label": "21142",
#           "metadata": []
#         },
#         "Country_id": {
#           "id": "r17$Country_id",
#           "label": "2840",
#           "metadata": []
#         },
#         "Keyword": {
#           "id": "r17$Keyword",
#           "label": "armed forces recruiting",
#           "metadata": []
#         },
#         "Impresiones": {
#           "id": "r17$Impresiones",
#           "label": "39",
#           "metadata": []
#         },
#         "Clicks": {
#           "id": "r17$Clicks",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc": {
#           "id": "r17$Cpc",
#           "label": "20000",
#           "metadata": []
#         },
#         "QualityScore": {
#           "id": "r17$QualityScore",
#           "label": "",
#           "metadata": []
#         },
#         "City": {
#           "id": "r17$City",
#           "label": "Brandon",
#           "metadata": [
#             {
#               "id": "georss:49.84937,-99.96192",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, MB, Canada",
#                 "uri": "http://www.google.com/maps/place/49.84937,-99.96192"
#               },
#               "score": 1,
#               "match": true,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:27.94015,-82.32543",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, FL, United States",
#                 "uri": "http://www.google.com/maps/place/27.94015,-82.32543"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:52.44274,0.62621",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, England, United Kingdom",
#                 "uri": "http://www.google.com/maps/place/52.44274,0.62621"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:32.27313,-89.98891",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, MS, United States",
#                 "uri": "http://www.google.com/maps/place/32.27313,-89.98891"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:43.80005,-73.09263",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, VT, United States",
#                 "uri": "http://www.google.com/maps/place/43.80005,-73.09263"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:43.59441,-96.57235",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, SD, United States",
#                 "uri": "http://www.google.com/maps/place/43.59441,-96.57235"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:-19.55431,147.35412",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, QLD 4808, Australia",
#                 "uri": "http://www.google.com/maps/place/-19.55431,147.35412"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:45.96393,-95.59951",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, MN, United States",
#                 "uri": "http://www.google.com/maps/place/45.96393,-95.59951"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:44.76241,-74.42118",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, NY, United States",
#                 "uri": "http://www.google.com/maps/place/44.76241,-74.42118"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:42.3145,-92.00643",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, IA, United States",
#                 "uri": "http://www.google.com/maps/place/42.3145,-92.00643"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:43.73449,-88.77773",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Brandon, WI, United States",
#                 "uri": "http://www.google.com/maps/place/43.73449,-88.77773"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             },
#             {
#               "id": "georss:65.6967,22.33465",
#               "feature": [
#                 {
#                   "id": "all_labels",
#                   "value": 100
#                 }
#               ],
#               "name": {
#                 "value": "Br\u00e4nd\u00f6n, Norrbotten County, Sweden",
#                 "uri": "http://www.google.com/maps/place/65.6967,22.33465"
#               },
#               "score": 1,
#               "match": false,
#               "type": [
#                 {
#                   "id": "wd:Q29934236",
#                   "name": "GlobeCoordinate"
#                 },
#                 {
#                   "id": "georss:point",
#                   "name": "point"
#                 }
#               ]
#             }
#           ]
#         },
#         "County": {
#           "id": "r17$County",
#           "label": "Florida",
#           "metadata": []
#         },
#         "Country": {
#           "id": "r17$Country",
#           "label": "United States",
#           "metadata": []
#         },
#         "Impresiones_q1": {
#           "id": "r17$Impresiones_q1",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_q3": {
#           "id": "r17$Impresiones_q3",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_med": {
#           "id": "r17$Impresiones_med",
#           "label": "1",
#           "metadata": []
#         },
#         "Impresiones_iqr": {
#           "id": "r17$Impresiones_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Impresiones_max": {
#           "id": "r17$Impresiones_max",
#           "label": "2794",
#           "metadata": []
#         },
#         "Impresiones_min": {
#           "id": "r17$Impresiones_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q1": {
#           "id": "r17$Clicks_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_q3": {
#           "id": "r17$Clicks_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_med": {
#           "id": "r17$Clicks_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_iqr": {
#           "id": "r17$Clicks_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Clicks_max": {
#           "id": "r17$Clicks_max",
#           "label": "148",
#           "metadata": []
#         },
#         "Clicks_min": {
#           "id": "r17$Clicks_min",
#           "label": "0",
#           "metadata": []
#         },
#         "Cpc_q1": {
#           "id": "r17$Cpc_q1",
#           "label": "160000",
#           "metadata": []
#         },
#         "Cpc_q3": {
#           "id": "r17$Cpc_q3",
#           "label": "620000",
#           "metadata": []
#         },
#         "Cpc_med": {
#           "id": "r17$Cpc_med",
#           "label": "300000",
#           "metadata": []
#         },
#         "Cpc_iqr": {
#           "id": "r17$Cpc_iqr",
#           "label": "460000",
#           "metadata": []
#         },
#         "Cpc_max": {
#           "id": "r17$Cpc_max",
#           "label": "999000000",
#           "metadata": []
#         },
#         "Cpc_min": {
#           "id": "r17$Cpc_min",
#           "label": "10000",
#           "metadata": []
#         },
#         "Qs_q1": {
#           "id": "r17$Qs_q1",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_q3": {
#           "id": "r17$Qs_q3",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_med": {
#           "id": "r17$Qs_med",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_iqr": {
#           "id": "r17$Qs_iqr",
#           "label": "0",
#           "metadata": []
#         },
#         "Qs_max": {
#           "id": "r17$Qs_max",
#           "label": "10",
#           "metadata": []
#         },
#         "Qs_min": {
#           "id": "r17$Qs_min",
#           "label": "0",
#           "metadata": []
#         },
#         "apparent_temperature_max": {
#           "id": "r17$apparent_temperature_max",
#           "label": "30,2",
#           "metadata": []
#         },
#         "apparent_temperature_min": {
#           "id": "r17$apparent_temperature_min",
#           "label": "16",
#           "metadata": []
#         },
#         "precipitation_sum": {
#           "id": "r17$precipitation_sum",
#           "label": "0",
#           "metadata": []
#         }
#       }
#     }
#   }
# }

# %%
from yarl import URL
url = URL('https://www.python.org/~guido?arg=1#frag')
url
# Out:
# URL('https://www.python.org/~guido?arg=1#frag')

# %%
SEMTUI_URI = URL(SEMTUI_URI)

# %%
testuri / 'extender'
# Out:
# URL('http://localhost:3003/api/extender')

# %%
res = requests.get(sempath)
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 res = requests.get(sempath)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:445, in PreparedRequest.prepare_url(self, url, params)
#     439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
# --> 445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#     447 # In general, we want to try IDNA encoding the hostname if the string contains
#     448 # non-ASCII characters. This allows users to automatically get the correct IDNA
#     449 # behaviour. For strings containing only ASCII characters, we need to also verify
#     450 # it doesn't start with a wildcard (*), before allowing the unencoded hostname.
#     451 if not unicode_is_ascii(host):
#
# InvalidURL: Invalid URL 'http:/localhost:3003/api': No host supplied
